# %% [markdown]
# # Markdown notation
#
# ## What you will learn in this class 🧐🧐
#
#
# When you develop and push content on Github, you often add a `README.md` file. This file is what Github will display by default when you open a repository. It's important to write it well because it's what will help you understand the project and how to approach it. If you have a well done `README.md` file, you'll get more help on your project! In this course, you will learn:
#
# * What is Markdown notation
# * How to format Markdown files
#
#
# ## What is Markdown
#
# Markdown is a lightweight markup language used to format text using simple, easy-to-read syntax. It allows users to create formatted documents with elements like headers, lists, links, images, and code blocks without the complexity of HTML. Markdown is widely used in websites, documentation, and readme files due to its simplicity and portability. It can be converted into various formats, such as HTML or PDF, making it versatile for different platforms. Its syntax is designed to be readable as plain text, even before being rendered into its final formatted form.
#
#
# ## Write headlines
#
# Nothing could be simpler, just put a _#_ to design that your text is a title. For example :
#
#
# ```markdown
# # This is a title
# ```
#
#
# The more #'s you add, the lower you go in the hierarchy of importance of the titles. For example:
#
#
# ```markdown
# ## This is a subtitle
# ### This is a sub-subtitle
# #### This is a sub-sub-subtitle
# ##### etc
# #### This is the maximum
# ```
#
#
#
# ### Stylize your texts
#
#
# You can italicize or bold your text with this code :
#
# ![](src/markdown.png)
#
#
# ### Add code to your texts
#
# Very often you will want to incorporate code into your file. You can do this simply by adding three counter-apostrophes before and after your code. For example, you can do this by adding three counter-apostrophes before and after your code:
#
#
#
# ```python
# for item in variable
#     print ("hello world")
# ```
#
#
# ### Put a link
#
# To put a link in Github, you have to proceed as follows:
#
#
# ```markdown
# [The text to link](the url to redirect to)
# ```
#
# For example
#
#
# ```markdown
# [Jedha](https://jedha.co)
# ```
#
#
# These are the main commands for writing your README.md . There are, of course, many more you can use. Feel free to look in the Resource section of the course for more information.
#
#
# ## Resources 📚📚
#
# * [Markdown Guide](https://www.markdownguide.org/)
