# %% [markdown]
# # Become a movie director
#
# Let's use Scrapy to get some information about the 250 top rated movies on <a href="http://www.imdb.com/" target="_blank">IMDB</a>.
#
# 1. Install `Scrapy`:

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (2.13.3)
# Requirement already satisfied: cryptography>=37.0.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (45.0.5)
# Requirement already satisfied: cssselect>=0.9.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (1.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (0.12.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: lxml>=4.6.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (6.0.0)
# Requirement already satisfied: packaging in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (24.2)
# Requirement already satisfied: parsel>=1.5.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (1.10.0)
# Requirement already satisfied: protego>=0.1.15 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (0.5.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: pyopenssl>=22.0.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (25.1.0)
# Requirement already satisfied: queuelib>=1.4.2 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (1.8.0)
# Requirement already satisfied: service-identity>=18.1.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: tldextract in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (5.3.0)
# Requirement already satisfied: twisted>=21.7.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (25.5.0)
# Requirement already satisfied: w3lib>=1.17.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (2.3.1)
# Requirement already satisfied: zope-interface>=5.1.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from scrapy) (7.2)
# Requirement already satisfied: cffi>=1.14 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from cryptography>=37.0.0->scrapy) (1.17.1)
# Requirement already satisfied: pycparser in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=37.0.0->scrapy) (2.21)
# Requirement already satisfied: jmespath>=0.9.5 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from service-identity>=18.1.0->scrapy) (24.3.0)
# Requirement already satisfied: pyasn1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from service-identity>=18.1.0->scrapy) (0.4.2)
# Requirement already satisfied: automat>=24.8.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from twisted>=21.7.0->scrapy) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from twisted>=21.7.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from twisted>=21.7.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from twisted>=21.7.0->scrapy) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from twisted>=21.7.0->scrapy) (4.12.2)
# Requirement already satisfied: idna>=2.5 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from hyperlink>=17.1.1->twisted>=21.7.0->scrapy) (3.7)
# Requirement already satisfied: setuptools>=61.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from incremental>=24.7.0->twisted>=21.7.0->scrapy) (72.1.0)
# Requirement already satisfied: requests>=2.1.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from tldextract->scrapy) (2.32.4)
# Requirement already satisfied: requests-file>=1.4 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from tldextract->scrapy) (3.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from requests>=2.1.0->tldextract->scrapy) (2025.7.14)

# %% [markdown]
# 2. Create a folder where you will store the scripts and results of this exercise. Create a file named `imdb1.py` in that folder.

# %% [markdown]
# 3. Start by writing code in the script to:
# * import os, logging, scrapy, and CrawlerProcess from scrapy.crawler

# %% [markdown]
# 4. Create a first spider called `imdb_spider` with:
# * name `imdb`
# * start_urls `https://www.imdb.com/chart/boxoffice`
#
# This spider should scrape the ranking, the title, the url, the total earnings, the rating and the number of voters for the first movie of the charts.
#
# Set up the `CrawlerProcess`.
# Save the results to a `imdb1.json` file.

# %%
# !python src/imdb1.py
# Out:
# 2025-08-13 14:45:13 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: scrapybot)
# 2025-08-13 14:45:13 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.0',
#  'libxml2': '2.14.4',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, '
#            '16:09:02) [GCC 11.2.0]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.1 1 Jul 2025)',
#  'cryptography': '45.0.5',
#  'Platform': 'Linux-6.14.0-27-generic-x86_64-with-glibc2.39'}
# 2025-08-13 14:45:13 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-08-13 14:45:13 [scrapy.extensions.telnet] INFO: Telnet Password: 9a8eac1ccd6ba2a8
# 2025-08-13 14:45:13 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-08-13 14:45:13 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Firefox/141.0'}
# 2025-08-13 14:45:13 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-08-13 14:45:13 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-08-13 14:45:13 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-08-13 14:45:13 [scrapy.core.engine] INFO: Spider opened
# 2025-08-13 14:45:13 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-08-13 14:45:13 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-08-13 14:45:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-08-13 14:45:14 [scrapy.extensions.feedexport] INFO: Stored json feed (1 items) in: src/imdb1.json
# 2025-08-13 14:45:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 421,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 168903,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/308': 1,
#  'elapsed_time_seconds': 1.11289,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 8, 13, 12, 45, 14, 398323, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 850672,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 1,
#  'items_per_minute': 60.0,
#  'log_count/INFO': 11,
#  'memusage/max': 71352320,
#  'memusage/startup': 71352320,
#  'response_received_count': 1,
#  'responses_per_minute': 60.0,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2025, 8, 13, 12, 45, 13, 285433, tzinfo=datetime.timezone.utc)}
# 2025-08-13 14:45:14 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# 5. Create a new script called `imdb2.py` where you'll scrape the same information for all the movies in the chart!

# %%
# Out:
# 2023-09-27 17:03:59 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-09-27 17:03:59 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.9.16 (main, Jan 11 2023, 16:05:54) - [GCC 11.2.0], pyOpenSSL 22.0.0 (OpenSSL 1.1.1t  7 Feb 2023), cryptography 38.0.4, Platform Linux-5.10.102.1-microsoft-standard-WSL2-x86_64-with-glibc2.31
# 2023-09-27 17:03:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-09-27 17:03:59 [py.warnings] WARNING: /home/antoineco/miniconda3/lib/python3.9/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-09-27 17:03:59 [scrapy.extensions.telnet] INFO: Telnet Password: 200d749b78b68a0e
# 2023-09-27 17:03:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-09-27 17:03:59 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2023-09-27 17:03:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-09-27 17:03:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-09-27 17:03:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-09-27 17:03:59 [scrapy.core.engine] INFO: Spider opened
# 2023-09-27 17:03:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-09-27 17:03:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-09-27 17:04:00 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-09-27 17:04:00 [scrapy.extensions.feedexport] INFO: Stored json feed (10 items) in: 01-Become_a_movie_director/imdb2.json
# 2023-09-27 17:04:00 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 429,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 127850,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/308': 1,
#  'elapsed_time_seconds': 0.86681,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 9, 27, 15, 4, 0, 218022, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 666999,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 10,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 88625152,
#  'memusage/startup': 88625152,
#  'response_received_count': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2023, 9, 27, 15, 3, 59, 351212, tzinfo=datetime.timezone.utc)}
# 2023-09-27 17:04:00 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Part 2 - Optional 💪💪
# 6. Based on the results obtained, create a list called `url_list` containing all the urls for the movies in the charts.

# %%
# Out:
# [{'ranking': '1',
#   'title': 'The Nun II',
#   'url': '/title/tt10160976/?ref_=chtbo_t_1',
#   'total_earnings': '$70M',
#   'rating': '5.9',
#   'nb_voters': '19K'},
#  {'ranking': '2',
#   'title': 'Expend4bles',
#   'url': '/title/tt3291150/?ref_=chtbo_t_2',
#   'total_earnings': '$8.7M',
#   'rating': '5.2',
#   'nb_voters': '5K'},
#  {'ranking': '3',
#   'title': 'A Haunting in Venice',
#   'url': '/title/tt22687790/?ref_=chtbo_t_3',
#   'total_earnings': '$26M',
#   'rating': '6.8',
#   'nb_voters': '20K'}]

# %%
# Out:
# 2023-09-27 17:04:16 [numexpr.utils] INFO: NumExpr defaulting to 8 threads.
#   ranking                 title                                url  \
# 0       1            The Nun II  /title/tt10160976/?ref_=chtbo_t_1
# 1       2           Expend4bles   /title/tt3291150/?ref_=chtbo_t_2
# 2       3  A Haunting in Venice  /title/tt22687790/?ref_=chtbo_t_3
# 3       4       The Equalizer 3  /title/tt17024450/?ref_=chtbo_t_4
# 4       5                Barbie   /title/tt1517268/?ref_=chtbo_t_5
#
#   total_earnings rating nb_voters
# 0           $70M    5.9       19K
# 1          $8.7M    5.2        5K
# 2           $26M    6.8       20K
# 3           $82M    7.1       21K
# 4          $631M    7.1      334K

# %%
# Out:
# url list: ['https://www.imdb.com/title/tt10160976/?ref_=chtbo_t_1', 'https://www.imdb.com/title/tt3291150/?ref_=chtbo_t_2', 'https://www.imdb.com/title/tt22687790/?ref_=chtbo_t_3']

# %% [markdown]
# 7. Store the list of urls to a file called `url_list.txt`

# %% [markdown]
# 8. Scrape all the pages from the movies in the charts and extract the complete cast, the Storyline, and the genres, also save the title and url for future joins purposes. *Pay attention to inconsistencies between pages*

# %%
# Out:
# 2023-09-27 17:04:47 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-09-27 17:04:47 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.9.16 (main, Jan 11 2023, 16:05:54) - [GCC 11.2.0], pyOpenSSL 22.0.0 (OpenSSL 1.1.1t  7 Feb 2023), cryptography 38.0.4, Platform Linux-5.10.102.1-microsoft-standard-WSL2-x86_64-with-glibc2.31
# 2023-09-27 17:04:47 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-09-27 17:04:47 [py.warnings] WARNING: /home/antoineco/miniconda3/lib/python3.9/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-09-27 17:04:47 [scrapy.extensions.telnet] INFO: Telnet Password: d1ce3247c5f87d50
# 2023-09-27 17:04:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-09-27 17:04:47 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2023-09-27 17:04:47 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-09-27 17:04:47 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-09-27 17:04:47 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-09-27 17:04:47 [scrapy.core.engine] INFO: Spider opened
# 2023-09-27 17:04:47 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-09-27 17:04:47 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-09-27 17:04:51 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-09-27 17:04:51 [scrapy.extensions.feedexport] INFO: Stored json feed (10 items) in: 01-Become_a_movie_director/imdb3.json
# 2023-09-27 17:04:51 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2308,
#  'downloader/request_count': 10,
#  'downloader/request_method_count/GET': 10,
#  'downloader/response_bytes': 1816339,
#  'downloader/response_count': 10,
#  'downloader/response_status_count/200': 10,
#  'elapsed_time_seconds': 3.721095,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 9, 27, 15, 4, 51, 506967, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10733090,
#  'httpcompression/response_count': 10,
#  'item_scraped_count': 10,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 118042624,
#  'memusage/startup': 118042624,
#  'response_received_count': 10,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2023, 9, 27, 15, 4, 47, 785872, tzinfo=datetime.timezone.utc)}
# 2023-09-27 17:04:51 [scrapy.core.engine] INFO: Spider closed (finished)
