# %% [markdown]
# # Scrapy advanced
#
# In this course we will dig further into scrapy's capabilities, which are numerous, and good enough to let you scrape even websites that are attempting to protect themselves from this practice (for example sites like google or facebook are particularly reluctant to being scraped because they do not want other people being able to leverage their users' data).

# %% [markdown]
# ## What you will learn in this course 🧐🧐
#
# This course will introduce the following concepts:
#
# * Callbacks
# * Web navigation with scrapy
# * Post requests with scrapy
# * Multiple spiders
# * Scrapy Projects
# * Avoid being banned
#     * Scrapy projects
#     * Autothrottle
#     * Rotate user agent
#     * Rotate IP address

# %% [markdown]
# ## Callbacks
#
# Callbacks are a way to call functions in our code at specific moments or when a specific task is done, depending on contraints and events that are partly or fully independent from the code itself. For example we may want to use callbacks when:
#
# * We want a function to run when a user clicks a certain button on an app
# * We want a function to run when the response from the webserver has been fully loaded
# * We want a function to run when a user lands on a specific url
#
# The list goes on.
# Scrapy uses a lot of callbacks for tasks that repeat over different pages, or if we want scrapy to follow link after link after link to explore a website.

# %% [markdown]
# ## Following pagination links 📄📄
#
# Scrapy simulates a web browser that will send requests to web servers, therefore it can do almost everything a web browser can do, such as naviagting the web using links! All you have to do is get the XPath from the link you are looking to click and use the `.follow` method.
# [This code example](https://julie-resources.s3.eu-west-3.amazonaws.com/full-stack-full-time/web-scraping-ft/scrapy-advanced-ft/scrapy3.py) shows how to use links to iterate over multiple pages:

# %%
# !pip install scrapy

# %%
# !python src/scrapy3.py
# Out:
# 2025-07-31 09:30:46 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: scrapybot)
# 2025-07-31 09:30:46 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.0',
#  'libxml2': '2.14.4',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, '
#            '16:09:02) [GCC 11.2.0]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.1 1 Jul 2025)',
#  'cryptography': '45.0.5',
#  'Platform': 'Linux-6.14.0-24-generic-x86_64-with-glibc2.39'}
# 2025-07-31 09:30:46 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-07-31 09:30:46 [scrapy.extensions.telnet] INFO: Telnet Password: da95d22848ca2643
# 2025-07-31 09:30:46 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-07-31 09:30:46 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Firefox/141.0'}
# 2025-07-31 09:30:46 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-07-31 09:30:46 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-07-31 09:30:46 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-07-31 09:30:46 [scrapy.core.engine] INFO: Spider opened
# 2025-07-31 09:30:46 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-07-31 09:30:46 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-07-31 09:30:48 [root] INFO: No next page. Terminating crawling process.
# 2025-07-31 09:30:48 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-07-31 09:30:48 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: src/3_quotesmultiplepages.json
# 2025-07-31 09:30:48 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2496,
#  'downloader/request_count': 10,
#  'downloader/request_method_count/GET': 10,
#  'downloader/response_bytes': 21903,
#  'downloader/response_count': 10,
#  'downloader/response_status_count/200': 10,
#  'elapsed_time_seconds': 2.251025,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 7, 31, 7, 30, 48, 669727, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 108671,
#  'httpcompression/response_count': 10,
#  'item_scraped_count': 100,
#  'items_per_minute': 3000.0,
#  'log_count/INFO': 12,
#  'memusage/max': 71856128,
#  'memusage/startup': 71856128,
#  'request_depth_max': 9,
#  'response_received_count': 10,
#  'responses_per_minute': 300.0,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2025, 7, 31, 7, 30, 46, 418702, tzinfo=datetime.timezone.utc)}
# 2025-07-31 09:30:48 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# The result from this scraping process may be found in [this file](src/3_quotesmultiplepages.json)

# %% [markdown]
# ## Authentication on a website 🔐🔐
#
# A very useful feature of Scrapy: you can simulate automatic authentication! More generally, you may fill out forms and submit them like any normal web users would!
#
# This can be done by using `scrapy.FormRequest.from_response()` to send a post request with some your login/password to the website.
#
# This method will look for a `<form>` tag in the response object (the html code of the url you requested) and will populate the different fields with data of your choice. The data should be given to the `formdata` argument in the form of a dictionnary `{key:value}` where the `key` is the id attribute of the form field and `value` is what you wish to write there. Automatically this method will look for any clickable or submit button in the form and click.
#
# You can take a look at the [documentation](https://docs.scrapy.org/en/latest/topics/request-response.html#formrequest-objects) to get a better understanding.
#
# You may see this in [this script](https://julie-resources.s3.eu-west-3.amazonaws.com/full-stack-full-time/web-scraping-ft/scrapy-advanced-ft/scrapy4.py).

# %%
# !python src/scrapy4.py
# Out:
# 2025-07-31 09:46:15 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: scrapybot)
# 2025-07-31 09:46:15 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.0',
#  'libxml2': '2.14.4',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, '
#            '16:09:02) [GCC 11.2.0]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.1 1 Jul 2025)',
#  'cryptography': '45.0.5',
#  'Platform': 'Linux-6.14.0-24-generic-x86_64-with-glibc2.39'}
# 2025-07-31 09:46:15 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-07-31 09:46:15 [scrapy.extensions.telnet] INFO: Telnet Password: 79333679d2c3698b
# 2025-07-31 09:46:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-07-31 09:46:15 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Firefox/141.0'}
# 2025-07-31 09:46:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-07-31 09:46:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-07-31 09:46:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-07-31 09:46:15 [scrapy.core.engine] INFO: Spider opened
# 2025-07-31 09:46:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-07-31 09:46:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-07-31 09:46:18 [root] INFO: No next page. Terminating crawling process.
# 2025-07-31 09:46:18 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-07-31 09:46:18 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: src/4_quotesauthentication.json
# 2025-07-31 09:46:18 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 4960,
#  'downloader/request_count': 12,
#  'downloader/request_method_count/GET': 11,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 24812,
#  'downloader/response_count': 12,
#  'downloader/response_status_count/200': 11,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 2.728054,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 7, 31, 7, 46, 18, 122116, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 119162,
#  'httpcompression/response_count': 11,
#  'item_scraped_count': 100,
#  'items_per_minute': 3000.0,
#  'log_count/INFO': 12,
#  'memusage/max': 71774208,
#  'memusage/startup': 71774208,
#  'request_depth_max': 10,
#  'response_received_count': 11,
#  'responses_per_minute': 330.0,
#  'scheduler/dequeued': 12,
#  'scheduler/dequeued/memory': 12,
#  'scheduler/enqueued': 12,
#  'scheduler/enqueued/memory': 12,
#  'start_time': datetime.datetime(2025, 7, 31, 7, 46, 15, 394062, tzinfo=datetime.timezone.utc)}
# 2025-07-31 09:46:18 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# The result of this query is available in [this file](src/4_quotesauthentication.json).

# %% [markdown]
# ## Run spiders with multiple starting urls 🕸️ 🕷️
#
# It is possible to run a spider using several starting urls. Take a look at the [code example](https://julie-resources.s3.eu-west-3.amazonaws.com/full-stack-full-time/web-scraping-ft/scrapy-advanced-ft/scrapy5.py).

# %%
# !python src/scrapy5.py
# Out:
# 2025-07-31 09:47:33 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: scrapybot)
# 2025-07-31 09:47:33 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.0',
#  'libxml2': '2.14.4',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, '
#            '16:09:02) [GCC 11.2.0]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.1 1 Jul 2025)',
#  'cryptography': '45.0.5',
#  'Platform': 'Linux-6.14.0-24-generic-x86_64-with-glibc2.39'}
# 2025-07-31 09:47:33 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-07-31 09:47:33 [scrapy.extensions.telnet] INFO: Telnet Password: a6d391adc2204ed4
# 2025-07-31 09:47:33 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-07-31 09:47:33 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Firefox/141.0'}
# 2025-07-31 09:47:33 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-07-31 09:47:33 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-07-31 09:47:33 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-07-31 09:47:33 [scrapy.core.engine] INFO: Spider opened
# 2025-07-31 09:47:33 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-07-31 09:47:33 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-07-31 09:47:34 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-07-31 09:47:34 [scrapy.extensions.feedexport] INFO: Stored json feed (20 items) in: src/5_quotesmultiplespiders.json
# 2025-07-31 09:47:34 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 418,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 5078,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.322168,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 7, 31, 7, 47, 34, 168820, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 24809,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 20,
#  'items_per_minute': None,
#  'log_count/INFO': 11,
#  'memusage/max': 71532544,
#  'memusage/startup': 71532544,
#  'response_received_count': 2,
#  'responses_per_minute': None,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2025, 7, 31, 7, 47, 33, 846652, tzinfo=datetime.timezone.utc)}
# 2025-07-31 09:47:34 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# You may take a look at the [result file](src/5_quotesmultiplespiders.json).

# %% [markdown]
# ## Avoid being banned
#
# Several websites are trying to protect themselves from scrapers because they do not want their data (which has a lot to do with their added value in most cases) to be captured by other people. This part of the lecture will focus on using scrapy's capabilities that make it harder to detect and therefore harder to be stopped by reluctant websites.

# %% [markdown]
# ### Scrapy projects
#
# Most of the techniques that can make your scraping processes harder to detect have nothing to do with the actual scraping code, that entirely depends on the webpage you are trying to scrape and its source code, it has everything to do with the configuration of everything that surrounds your spider.
#
# In order to easily access the configuration files of the scraping process and set up everything painlessly we can use what we call scrapy projects.

# %%
import os
os.chdir("src")
os.getcwd()
# Out:
# '/home/storage/Documents/DataScience_Jedha/Fullstack/DataCollectionAndManagement/2-WebScraping/src'

# %%
# !scrapy startproject tutorial
# Out:
# New Scrapy project 'tutorial', using template directory '/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/templates/project', created in:
#     /home/storage/Documents/DataScience_Jedha/Fullstack/DataCollectionAndManagement/2-WebScraping/src/tutorial
#
# You can start your first spider with:
#     cd tutorial
#     scrapy genspider example example.com

# %% [markdown]
# Here's how the scrapy project will appear in your current working directory:
#
# ```
# ├── tutorial
# │   ├── tutorial
# │   │   ├── spiders
# │   │   │   └── __init__.py
# │   │   ├── __init__.py
# │   │   ├── items.py
# │   │   ├── middlewares.py
# │   │   ├── pipelines.py
# │   │   └── settings.py
# │   └── scrapy.cfg
# ```
#
# We will define the spiders we wish to use to scrape the web in the `spiders` folder. The python files and the `cfg` file we will use to configure the way the spider script will be run.

# %% [markdown]
# ## Autothrottle 🚫🚫
#
# The more scraping you're doing the more requests you make. If websites are well protected, they might ban you because you exceeded requests limitations.
#
# You may avoid that by delaying the number of requests automatically thanks to the `AutoThrottle` extension.
#
# As stated in the documentation, `AutoThrottle` extension is designed to:
#
# - *Be nicer to sites instead of using default download delay of zero.*
# - *Automatically adjust Scrapy to the optimum crawling speed, so the user doesn’t have to tune the download delays to find the optimum one. The user only needs to specify the maximum concurrent requests it allows, and the extension does the rest.*
#
# To use autothrottle, it's as simple as adding `"AUTOTHROTTLE_ENABLED": True` to your crawler's settings. If you are working with scrapy projects (as you should if you are trying to do some intense scraping) you only need to uncomment the appropriate line in the [settings.py](src/tutorial/tutorial/settings.py) file.

# %%
os.chdir("tutorial")
os.getcwd()
# Out:
# '/home/storage/Documents/DataScience_Jedha/Fullstack/DataCollectionAndManagement/2-WebScraping/src/tutorial/tutorial'

# %% [markdown]
# To launch a spider contained in a scrapy project, all you have to do is `cd` into the project directory (in our case `tutorial`) then run the following command:
#
# `!scrapy crawl name_of_the_spider -O filename_to_save_the_results`

# %%
# !scrapy crawl autothrottle -O results/6_quotesautothrottle.json
# Out:
# 2025-07-31 09:59:59 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: tutorial)
# 2025-07-31 09:59:59 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.0',
#  'libxml2': '2.14.4',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, '
#            '16:09:02) [GCC 11.2.0]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.1 1 Jul 2025)',
#  'cryptography': '45.0.5',
#  'Platform': 'Linux-6.14.0-24-generic-x86_64-with-glibc2.39'}
# Traceback (most recent call last):
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/spiderloader.py", line 106, in load
#     return self._spiders[spider_name]
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^
# KeyError: 'autothrottle'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/brice/anaconda3/envs/jedha/bin/scrapy", line 8, in <module>
#     sys.exit(execute())
#              ~~~~~~~^^
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/cmdline.py", line 205, in execute
#     _run_print_help(parser, _run_command, cmd, args, opts)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/cmdline.py", line 158, in _run_print_help
#     func(*a, **kw)
#     ~~~~^^^^^^^^^^
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/cmdline.py", line 213, in _run_command
#     cmd.run(args, opts)
#     ~~~~~~~^^^^^^^^^^^^
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/commands/crawl.py", line 33, in run
#     crawl_defer = self.crawler_process.crawl(spname, **opts.spargs)
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/crawler.py", line 338, in crawl
#     crawler = self.create_crawler(crawler_or_spidercls)
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/crawler.py", line 374, in create_crawler
#     return self._create_crawler(crawler_or_spidercls)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/crawler.py", line 458, in _create_crawler
#     spidercls = self.spider_loader.load(spidercls)
#   File "/home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages/scrapy/spiderloader.py", line 108, in load
#     raise KeyError(f"Spider not found: {spider_name}")
# KeyError: 'Spider not found: autothrottle'

# %% [markdown]
# ### Rotate the user agent
#
# In some cases, websites do not expect the same browser to make multiple requests in a short amount of time, this is why rotating user agents can be useful not to get caught scraping by the website.
#
# All you will have to do is install the `scrapy-user-agents` library and then include this code in the `settings.py` file:
#
# ```python
# DOWNLOADER_MIDDLEWARES = {
#     'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware': None,
#     'scrapy_user_agents.middlewares.RandomUserAgentMiddleware': 400,
# }
# ```

# %%
# !pip install scrapy-user-agents

# %%
os.chdir("..")
os.getcwd()

# %%
# !scrapy startproject rotate_user_agent

# %%
os.chdir("rotate_user_agent")
os.getcwd()

# %%
# !scrapy crawl rotate_user_agent -O results/rotate_user_agent.json

# %% [markdown]
# ### Rotate IP addresses
#
# A very easy way to detect scrapers is to count the number of calls made by the same IP address in a given amount of time. An easy solution for this is to rotate between proxies that will act as an intermediary between your web client and the web server, making it see IP addresses that are not yours.
#
# First we need to install the `scrapy-rotating-proxy` library.
#
# All you have to do is find a list of proxies and add it to the `settings.py` file in the following way:
#
# ```python
# ROTATING_PROXY_LIST = [
#     'Proxy_IP:port',
#     'Proxy_IP:port',
#     # ...
# ]
# ```
#
# Or you could also get the proxy list from file:
#
# ```python
# ROTATING_PROXY_LIST_PATH = 'listofproxies.txt'
# ```
#
# We'll use proxies given in the [proxy list file](https://julie-resources.s3.eu-west-3.amazonaws.com/full-stack-full-time/web-scraping-ft/scrapy-advanced-ft/Free_Proxy_List.csv).

# %%
# !pip install scrapy-rotating-proxies

# %%
os.chdir("..")
os.getcwd()

# %%
import pandas as pd

proxy = pd.read_csv("Free_Proxy_List.csv")
proxy

# %%
proxy_list = [f"{row[0]}:{row[1]}" for row in zip(proxy["ip"],proxy["port"])]
proxy_list[:3]

# %%
textfile = open("proxy.txt", "w")
for element in proxy_list:
    textfile.write(element + "\n")
textfile.close()

# %%
# !scrapy startproject rotate_proxy

# %%
os.chdir("rotate_proxy")

# %%
# !scrapy crawl rotate_proxy -O results/8_rotate_proxy.json

# %% [markdown]
# ## Ressources 📚📚
#
# [Rotate user agent](https://python.plainenglish.io/rotating-user-agent-with-scrapy-78ca141969fe)
#
# [Rotate proxies](https://medium.com/@TeraCrawler.io/how-to-rotate-proxies-in-scrapy-2bccf38439f7)
