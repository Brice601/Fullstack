# %% [markdown]
# # Just look up!
#
# This exercise will let you deal with an API which documentation is a little bit more compicated to navigate than the previous one. We'll call an API to get air quality measures for France. Though the API lets you get data from anywhere in the world we have chosen to focus this study on France, but feel free to start with any country of your choice the series of questions would still hold.

# %% [markdown]
# 1. Go to [https://docs.openaq.org/](https://docs.openaq.org/) and try a first call to make sure the APi is working properly!

# %%
import requests
import pandas as pd
import json

base_url = "https://api.openaq.org/v3/locations/8118"

headers = {
    "X-API-Key": "06c205979345016647310d366711deaa647d0ce0d5951f0d70dfcea13298db62"
}

response = requests.get(base_url, headers=headers)

# ou dans terminal curl --request GET --url "https://api.openaq.org/v3/locations/8118" --header "X-API-Key: 06c205979345016647310d366711deaa647d0ce0d5951f0d70dfcea13298db62"

response
# Out:
# <Response [200]>

# %% [markdown]
# 2. Before we start getting information from the API, let's take a look at the different types of air quality measures that are available to us and their definition. Query the API to get all the different possible **parameters** and their definitions.

# %%
url_params= "https://api.openaq.org/v3/parameters"
headers = {
    "X-API-Key": "06c205979345016647310d366711deaa647d0ce0d5951f0d70dfcea13298db62"
}

response_data = requests.get(url_params, headers=headers)

response_data.content
# Out:
# b'{"meta":{"name":"openaq-api","website":"/","page":1,"limit":100,"found":40},"results":[{"id":1,"name":"pm10","units":"\xc2\xb5g/m\xc2\xb3","displayName":"PM10","description":"Particulate matter less than 10 micrometers in diameter mass concentration"},{"id":2,"name":"pm25","units":"\xc2\xb5g/m\xc2\xb3","displayName":"PM2.5","description":"Particulate matter less than 2.5 micrometers in diameter mass concentration"},{"id":3,"name":"o3","units":"\xc2\xb5g/m\xc2\xb3","displayName":"O\xe2\x82\x83 mass","description":"Ozone mass concentration"},{"id":4,"name":"co","units":"\xc2\xb5g/m\xc2\xb3","displayName":"CO mass","description":"Carbon Monoxide mass concentration"},{"id":5,"name":"no2","units":"\xc2\xb5g/m\xc2\xb3","displayName":"NO\xe2\x82\x82 mass","description":"Nitrogen Dioxide mass concentration"},{"id":6,"name":"so2","units":"\xc2\xb5g/m\xc2\xb3","displayName":"SO\xe2\x82\x82 mass","description":"Sulfur Dioxide mass concentration"},{"id":7,"name":"no2","units":"ppm","displayName":"NO\xe2\x82\x82","description":"Nitrogen Dioxide concentration"},{"id":8,"name":"co","units":"ppm","displayName":"CO","description":"Carbon Monoxide concentration"},{"id":9,"name":"so2","units":"ppm","displayName":"SO\xe2\x82\x82","description":"Sulfur Dioxide concentration"},{"id":10,"name":"o3","units":"ppm","displayName":"O\xe2\x82\x83","description":"Ozone concentration"},{"id":11,"name":"bc","units":"\xc2\xb5g/m\xc2\xb3","displayName":"BC","description":"Black Carbon mass concentration"},{"id":15,"name":"no2","units":"ppb","displayName":"NO\xe2\x82\x82","description":null},{"id":19,"name":"pm1","units":"\xc2\xb5g/m\xc2\xb3","displayName":"PM1","description":"Particulate matter less than 1 micrometer in diameter mass concentration"},{"id":21,"name":"co2","units":"ppm","displayName":"CO\xe2\x82\x82","description":"Carbon Dioxide concentration"},{"id":22,"name":"wind_direction","units":"deg","displayName":"Wind direction","description":"Direction that the wind originates from"},{"id":23,"name":"nox","units":"ppb","displayName":"NOX","description":null},{"id":24,"name":"no","units":"ppb","displayName":"NO","description":null},{"id":27,"name":"nox","units":"\xc2\xb5g/m\xc2\xb3","displayName":"NOx mass","description":"Nitrogen Oxides mass concentration"},{"id":28,"name":"ch4","units":"ppm","displayName":"CH\xe2\x82\x84","description":"Methane concentration"},{"id":32,"name":"o3","units":"ppb","displayName":"O\xe2\x82\x83","description":null},{"id":33,"name":"ufp","units":"particles/cm\xc2\xb3","displayName":"UFP count","description":"Ultrafine Particles count concentration"},{"id":34,"name":"wind_speed","units":"m/s","displayName":"Wind speed","description":"Average wind speed in meters per second"},{"id":35,"name":"no","units":"ppm","displayName":"NO","description":"Nitrogen Monoxide concentration"},{"id":95,"name":"pressure","units":"hpa","displayName":"Atmospheric pressure","description":"Atmospheric or barometric pressure"},{"id":97,"name":"pm25-old","units":"ugm3","displayName":null,"description":null},{"id":98,"name":"relativehumidity","units":"%","displayName":"RH","description":null},{"id":100,"name":"temperature","units":"c","displayName":"Temperature (C)","description":null},{"id":101,"name":"so2","units":"ppb","displayName":"SO\xe2\x82\x82","description":null},{"id":102,"name":"co","units":"ppb","displayName":"CO","description":null},{"id":125,"name":"um003","units":"particles/cm\xc2\xb3","displayName":"PM0.3 count","description":null},{"id":126,"name":"um010","units":"particles/cm\xc2\xb3","displayName":"PM1 count","description":"PM1 count"},{"id":128,"name":"temperature","units":"f","displayName":"Temperature (F)","description":null},{"id":130,"name":"um025","units":"particles/cm\xc2\xb3","displayName":"PM2.5 count","description":"PM2.5 count"},{"id":132,"name":"pressure","units":"mb","displayName":"Pressure","description":null},{"id":134,"name":"humidity","units":"%","displayName":"H","description":null},{"id":135,"name":"um100","un ...

# %% [markdown]
# In what follows we will only focus on the `pm25` parameter which indicates the concentration of *fine particles* in the air, which is one of the most commonly discussed air pollution type.

# %% [markdown]
# 3. Use a query to list the countries available in API

# %%
pm25 = f"{url_params}/2"

response_pm25 = requests.get(pm25, headers=headers)

response_pm25.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'id': 2,
#    'name': 'pm25',
#    'units': 'µg/m³',
#    'displayName': 'PM2.5',
#    'description': 'Particulate matter less than 2.5 micrometers in diameter mass concentration'}]}

# %%
url_country = "https://api.openaq.org/v3/countries"

response_country = requests.get(url_country, headers=headers)

response_country.json()["results"]
# Out:
# [{'id': 1,
#   'code': 'ID',
#   'name': 'Indonesia',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 21, 'name': 'co2', 'units': 'ppm', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 130,
#     'name': 'um025',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 2,
#   'code': 'MY',
#   'name': 'Malaysia',
#   'datetimeFirst': '2022-11-03T21:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 3,
#   'code': 'CL',
#   'name': 'Chile',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 5,
#   'code': 'PE',
#   'name': 'Peru',
#   'datetimeFirst': '2016-03-04T17:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 6,
#   'code': 'AR',
#   'name': 'Argentina',
#   'datetimeFirst': '2016-01-01T03:00:00Z',
#   'datetimeLast': '2025-08-14T03:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 7,
#   'code': '-99',
#   'name': 'Dhekelia',
#   'datetimeFirst': '2023-03-19T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 8,
#   'code': 'CY',
#   'name': 'Cyprus',
#   'datetimeFirst': '2020-04-20T16:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 9,
#   'code': 'IN',
#   'name': 'India',
#   'datetimeFirst': '2016-01-30T00:30:00Z',
#   'datetimeLast': '2025-08-13T08:30:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 22, 'name': 'wind_direction', 'units': 'deg', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 34, 'name': 'wind_speed', 'units': 'm/s', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 102, 'name': 'co', 'units': 'ppb', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 10,
#   'code': 'CN',
#   'name': 'China',
#   'datetimeFirst': '2016-01-01T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 11,
#   'code': 'IL',
#   'name': 'Israel',
#   'datetimeFirst': '2016-01-01T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 23, 'name': 'nox', 'units': 'ppb', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 32, 'name': 'o3', 'units': 'ppb', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#  {'id': 12,
#   'code': 'PS',
#   'name': 'Palestine',
#   'datetimeFirst': '2017-08-10T23:00:00Z',
#   'datetimeLast': '2025-01-08T17:25:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 23, 'name': 'nox', 'units': 'ppb', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 32, 'name': 'o3', 'units': 'ppb', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#  {'id': 14,
#   'code': 'ET',
#   'name': 'Ethiopia',
#   'datetimeFirst': '2016-08-18T23:00:00Z',
#   'datetimeLast': '2025-08-13T07:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 15,
#   'code': 'SS',
#   'name': 'South Sudan',
#   'datetimeFirst': None,
#   'datetimeLast': None,
#   'parameters': None},
#  {'id': 17,
#   'code': 'KE',
#   'name': 'Kenya',
#   'datetimeFirst': '2018-04-21T00:00:00Z',
#   'datetimeLast': '2025-08-13T08:02:07.520000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 18,
#   'code': 'MW',
#   'name': 'Malawi',
#   'datetimeFirst': '2025-04-26T18:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 22,
#   'code': 'FR',
#   'name': 'France',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2025-08-13T08:05:53.037000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 24,
#   'code': 'GY',
#   'name': 'Guyana',
#   'datetimeFirst': '2024-10-02T12:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 25,
#   'code': 'KR',
#   'name': 'Republic of Korea',
#   'datetimeFirst': '2020-10-12T06:00:00Z',
#   'datetimeLast': '2025-08-13T08:07:02.573000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 27,
#   'code': 'MA',
#   'name': 'Morocco',
#   'datetimeFirst': '2024-04-04T10:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 29,
#   'code': 'CR',
#   'name': 'Costa Rica',
#   'datetimeFirst': '2019-10-28T18:00:00Z',
#   'datetimeLast': '2025-08-13T07:53:01.532000Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 32,
#   'code': 'CD',
#   'name': 'Democratic Republic of the Congo',
#   'datetimeFirst': '2022-06-16T17:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 34,
#   'code': 'UA',
#   'name': 'Ukraine',
#   'datetimeFirst': '2023-09-12T17:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 37,
#   'code': 'ZA',
#   'name': 'South Africa',
#   'datetimeFirst': '2016-02-14T08:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 38,
#   'code': 'MF',
#   'name': 'Saint-Martin',
#   'datetimeFirst': '2024-01-28T23:00:00Z',
#   'datetimeLast': '2025-08-13T02:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 40,
#   'code': 'OM',
#   'name': 'Oman',
#   'datetimeFirst': '2022-10-28T16:00:00Z',
#   'datetimeLast': '2024-05-20T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 41,
#   'code': 'UZ',
#   'name': 'Uzbekistan',
#   'datetimeFirst': '2018-11-27T22:00:00Z',
#   'datetimeLast': '2025-06-29T19:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 42,
#   'code': 'KZ',
#   'name': 'Kazakhstan',
#   'datetimeFirst': '2018-07-27T17:00:00Z',
#   'datetimeLast': '2025-08-13T08:05:41.326000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 43,
#   'code': 'TJ',
#   'name': 'Tajikistan',
#   'datetimeFirst': '2019-10-20T23:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 44,
#   'code': 'LT',
#   'name': 'Lithuania',
#   'datetimeFirst': '2017-09-21T23:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 45,
#   'code': 'BR',
#   'name': 'Brazil',
#   'datetimeFirst': '2017-07-01T00:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 46,
#   'code': 'UY',
#   'name': 'Uruguay',
#   'datetimeFirst': '2023-10-19T22:00:00Z',
#   'datetimeLast': '2023-10-21T10:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#  {'id': 47,
#   'code': 'MN',
#   'name': 'Mongolia',
#   'datetimeFirst': '2016-01-30T00:15:00Z',
#   'datetimeLast': '2025-08-13T08:04:34.493000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 48,
#   'code': 'RU',
#   'name': 'Russian Federation',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2021-08-09T11:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 49,
#   'code': 'CZ',
#   'name': 'Czech Republic',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 50,
#   'code': 'DE',
#   'name': 'Germany',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2025-08-13T08:04:14.946000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 51,
#   'code': 'EE',
#   'name': 'Estonia',
#   'datetimeFirst': '2020-04-20T20:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 52,
#   'code': 'LV',
#   'name': 'Latvia',
#   'datetimeFirst': '2017-09-22T10:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 53,
#   'code': 'NO',
#   'name': 'Norway',
#   'datetimeFirst': '2016-12-02T10:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 54,
#   'code': 'SE',
#   'name': 'Sweden',
#   'datetimeFirst': '2017-02-08T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 55,
#   'code': 'FI',
#   'name': 'Finland',
#   'datetimeFirst': '2016-12-10T19:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 56,
#   'code': 'VN',
#   'name': 'Vietnam',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:50:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 57,
#   'code': 'KH',
#   'name': 'Cambodia',
#   'datetimeFirst': '2025-03-27T03:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 58,
#   'code': 'LU',
#   'name': 'Luxembourg',
#   'datetimeFirst': '2017-09-22T10:00:00Z',
#   'datetimeLast': '2025-08-13T07:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 59,
#   'code': 'AE',
#   'name': 'United Arab Emirates',
#   'datetimeFirst': '2019-11-25T17:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 60,
#   'code': 'BE',
#   'name': 'Belgium',
#   'datetimeFirst': '2016-11-17T23:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 62,
#   'code': 'MK',
#   'name': 'North Macedonia',
#   'datetimeFirst': '2016-12-10T20:00:00Z',
#   'datetimeLast': '2025-08-13T08:06:13.737000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 64,
#   'code': 'AZ',
#   'name': 'Azerbaijan',
#   'datetimeFirst': '2022-06-23T13:00:00Z',
#   'datetimeLast': '2025-03-04T12:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 65,
#   'code': 'XK',
#   'name': 'Kosovo',
#   'datetimeFirst': '2016-04-08T20:00:00Z',
#   'datetimeLast': '2025-08-13T07:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 66,
#   'code': 'TR',
#   'name': 'Turkey',
#   'datetimeFirst': '2016-12-12T06:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 67,
#   'code': 'ES',
#   'name': 'Spain',
#   'datetimeFirst': '2016-11-17T23:00:00Z',
#   'datetimeLast': '2025-08-13T08:58:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 134, 'name': 'humidity', 'units': '%', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19844, 'name': 'pm4', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 68,
#   'code': 'LA',
#   'name': 'Lao PDR',
#   'datetimeFirst': '2019-06-16T02:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 69,
#   'code': 'KG',
#   'name': 'Kyrgyzstan',
#   'datetimeFirst': '2019-03-08T20:00:00Z',
#   'datetimeLast': '2025-03-31T07:05:38.501000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 121,
#   'code': 'MC',
#   'name': 'Monaco',
#   'datetimeFirst': '2023-09-25T16:11:07Z',
#   'datetimeLast': '2023-09-25T16:46:07Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 122,
#   'code': 'DZ',
#   'name': 'Algeria',
#   'datetimeFirst': '2019-06-15T22:00:00Z',
#   'datetimeLast': '2025-03-24T12:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 123,
#   'code': 'MZ',
#   'name': 'Mozambique',
#   'datetimeFirst': '2024-01-18T19:00:00Z',
#   'datetimeLast': '2025-03-24T23:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 70,
#   'code': 'AM',
#   'name': 'Armenia',
#   'datetimeFirst': '2022-11-14T09:00:00Z',
#   'datetimeLast': '2025-08-13T08:06:47.750000Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 71,
#   'code': 'DK',
#   'name': 'Denmark',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 74,
#   'code': 'RO',
#   'name': 'Romania',
#   'datetimeFirst': '2020-04-19T21:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 75,
#   'code': 'HU',
#   'name': 'Hungary',
#   'datetimeFirst': '2016-12-12T14:00:00Z',
#   'datetimeLast': '2025-08-13T23:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 76,
#   'code': 'SK',
#   'name': 'Slovakia',
#   'datetimeFirst': '2016-11-18T05:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 77,
#   'code': 'PL',
#   'name': 'Poland',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 78,
#   'code': 'IE',
#   'name': 'Ireland',
#   'datetimeFirst': '2016-12-10T21:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 79,
#   'code': 'GB',
#   'name': 'United Kingdom',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
# ...
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 100,
#   'code': 'NG',
#   'name': 'Nigeria',
#   'datetimeFirst': '2019-04-26T08:00:00Z',
#   'datetimeLast': '2025-08-13T08:01:26.286000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 103,
#   'code': 'HR',
#   'name': 'Croatia',
#   'datetimeFirst': '2016-11-17T22:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 102, 'name': 'co', 'units': 'ppb', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 104,
#   'code': 'SI',
#   'name': 'Slovenia',
#   'datetimeFirst': '2016-11-17T22:00:00Z',
#   'datetimeLast': '2025-08-13T08:06:48.373000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 105,
#   'code': 'QA',
#   'name': 'Qatar',
#   'datetimeFirst': '2022-04-11T15:00:00Z',
#   'datetimeLast': '2025-03-04T12:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 106,
#   'code': 'SA',
#   'name': 'Saudi Arabia',
#   'datetimeFirst': '2019-07-15T19:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 108,
#   'code': 'ZW',
#   'name': 'Zimbabwe',
#   'datetimeFirst': '2025-01-09T15:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 109,
#   'code': 'PK',
#   'name': 'Pakistan',
#   'datetimeFirst': '2019-05-22T22:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 110,
#   'code': 'BG',
#   'name': 'Bulgaria',
#   'datetimeFirst': '2020-04-20T18:00:00Z',
#   'datetimeLast': '2025-08-13T08:59:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 102, 'name': 'co', 'units': 'ppb', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 132, 'name': 'pressure', 'units': 'mb', 'displayName': None},
#    {'id': 134, 'name': 'humidity', 'units': '%', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19844, 'name': 'pm4', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 111,
#   'code': 'TH',
#   'name': 'Thailand',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2025-08-13T08:02:53.639000Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 112,
#   'code': 'SM',
#   'name': 'San Marino',
#   'datetimeFirst': '2017-11-01T23:00:00Z',
#   'datetimeLast': '2025-08-12T11:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 115,
#   'code': 'TD',
#   'name': 'Chad',
#   'datetimeFirst': '2020-08-02T20:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 116,
#   'code': 'KW',
#   'name': 'Kuwait',
#   'datetimeFirst': '2017-02-17T21:00:00Z',
#   'datetimeLast': '2025-03-04T12:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 199,
#   'code': 'TT',
#   'name': 'Trinidad and Tobago',
#   'datetimeFirst': '2023-03-30T10:00:00Z',
#   'datetimeLast': '2025-07-11T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 118,
#   'code': 'GT',
#   'name': 'Guatemala',
#   'datetimeFirst': '2019-10-20T21:00:00Z',
#   'datetimeLast': '2025-03-24T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 126,
#   'code': 'RW',
#   'name': 'Rwanda',
#   'datetimeFirst': '2020-12-28T23:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None}]},
#  {'id': 127,
#   'code': 'MM',
#   'name': 'Myanmar',
#   'datetimeFirst': '2019-06-16T08:00:00Z',
#   'datetimeLast': '2025-03-24T23:30:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 128,
#   'code': 'BD',
#   'name': 'Bangladesh',
#   'datetimeFirst': '2016-03-10T22:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 129,
#   'code': 'AD',
#   'name': 'Andorra',
#   'datetimeFirst': '2017-09-14T23:00:00Z',
#   'datetimeLast': '2025-08-13T07:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 130,
#   'code': 'AF',
#   'name': 'Afghanistan',
#   'datetimeFirst': '2019-10-20T23:00:00Z',
#   'datetimeLast': '2021-08-16T18:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 131,
#   'code': 'ME',
#   'name': 'Montenegro',
#   'datetimeFirst': '2022-03-24T14:00:00Z',
#   'datetimeLast': '2025-08-13T07:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 132,
#   'code': 'BA',
#   'name': 'Bosnia and Herzegovina',
#   'datetimeFirst': '2016-04-26T22:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 133,
#   'code': 'UG',
#   'name': 'Uganda',
#   'datetimeFirst': '2017-02-18T02:00:00Z',
#   'datetimeLast': '2025-03-24T13:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 136,
#   'code': 'HN',
#   'name': 'Honduras',
#   'datetimeFirst': '2024-11-30T18:00:00Z',
#   'datetimeLast': '2025-08-13T08:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 137,
#   'code': 'EC',
#   'name': 'Ecuador',
#   'datetimeFirst': '2020-12-29T05:00:00Z',
#   'datetimeLast': '2025-04-04T04:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]}]

# %% [markdown]
# 4. Use the previous query to find the two letter code for France (or the country of your choice) and use a query to get information about the country

# %%
# IMPORTANT : Parser la réponse JSON
countries_data = response_country.json()
countries_list = countries_data["results"]  # Accéder à la liste des pays

france_id = None
for country in countries_list:
    if country["code"] == "FR":
        france_id = country["id"]
        print(f"France ID: {france_id}")
        print(f"Données France: {country}")
        break
# Out:
# France ID: 22
# Données France: {'id': 22, 'code': 'FR', 'name': 'France', 'datetimeFirst': '2016-11-21T11:00:00Z', 'datetimeLast': '2025-08-13T08:05:53.037000Z', 'parameters': [{'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': None}, {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None}, {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None}, {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None}, {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}, {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}, {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None}, {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None}, {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}, {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None}, {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]}

# %%
url_FR = "https://api.openaq.org/v3/countries/22"

response_FR = requests.get(url_FR, headers=headers)

response_FR.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'id': 22,
#    'code': 'FR',
#    'name': 'France',
#    'datetimeFirst': '2016-11-21T11:00:00Z',
#    'datetimeLast': '2025-08-13T09:06:40.699000Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]}]}

# %% [markdown]
# 5. specifically store the number of available locations in a variable called `limit`

# %% [markdown]
# After a few trials it actually turns out that the actual number of locations available is a little higher than what the API gives us. In the following question set the limit parameter of the query to the maximum value in order to get all locations.

# %% [markdown]
# 6. Use a query to list out all the different locations in France, use a parameter to be able to get them all in one query!

# %%
# Out:
# status code: <Response [200]>
#
#
# Response data:
# [{'id': 226298,
#   'name': 'F4KLO-DP',
#   'entity': 'community',
#   'country': 'FR',
#   'sources': [{'id': 'purpleair',
#     'url': 'https://www2.purpleair.com/',
#     'name': 'PurpleAir'}],
#   'isMobile': False,
#   'parameters': [{'id': 1306985,
#     'unit': 'particles/cm³',
#     'count': 620346,
#     'average': 0.131211643179774,
#     'lastValue': 0.11,
#     'parameter': 'um025',
#     'displayName': 'PM2.5 count',
#     'lastUpdated': '2022-03-22T02:22:37+00:00',
#     'parameterId': 130,
#     'firstUpdated': '2021-05-14T08:11:42+00:00'},
#    {'id': 1306987,
#     'unit': 'µg/m³',
#     'count': 620346,
#     'average': 19.5628163960113,
#     'lastValue': 20.9,
#     'parameter': 'pm10',
#     'displayName': 'PM10',
#     'lastUpdated': '2022-03-22T02:22:37+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2021-05-14T08:11:42+00:00'},
#    {'id': 1306988,
#     'unit': 'µg/m³',
#     'count': 620346,
#     'average': 16.6822552253097,
#     'lastValue': 19.2,
#     'parameter': 'pm25',
#     'displayName': 'PM2.5',
#     'lastUpdated': '2022-03-22T02:22:37+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2021-05-14T08:11:42+00:00'},
#    {'id': 1306989,
#     'unit': 'µg/m³',
#     'count': 620346,
#     'average': 9.93757725527367,
#     'lastValue': 11.5,
#     'parameter': 'pm1',
#     'displayName': 'PM1',
#     'lastUpdated': '2022-03-22T02:22:37+00:00',
#     'parameterId': 19,
#     'firstUpdated': '2021-05-14T08:11:42+00:00'},
#    {'id': 1306984,
#     'unit': 'particles/cm³',
#     'count': 620346,
#     'average': 0.00380684005377642,
#     'lastValue': 0,
#     'parameter': 'um100',
#     'displayName': 'PM10 count',
#     'lastUpdated': '2022-03-22T02:22:37+00:00',
#     'parameterId': 135,
#     'firstUpdated': '2021-05-14T08:11:42+00:00'},
#    {'id': 1306986,
#     'unit': 'particles/cm³',
#     'count': 620346,
#     'average': 1.31079525780774,
#     'lastValue': 1.28,
#     'parameter': 'um010',
#     'displayName': 'PM1 count',
#     'lastUpdated': '2022-03-22T02:22:37+00:00',
#     'parameterId': 126,
#     'firstUpdated': '2021-05-14T08:11:42+00:00'}],
#   'sensorType': 'low-cost sensor',
#   'coordinates': {'latitude': 48.894, 'longitude': 2.388},
#   'lastUpdated': '2022-03-22T02:22:37+00:00',
#   'firstUpdated': '2021-05-14T08:11:42+00:00',
#   'measurements': 3722076},
#  {'id': 272915,
#   'name': 'Les hauts de la Pélouque',
#   'entity': 'community',
#   'country': 'FR',
#   'sources': [{'id': 'purpleair',
#     'url': 'https://www2.purpleair.com/',
#     'name': 'PurpleAir'}],
#   'isMobile': False,
#   'parameters': [{'id': 1564946,
#     'unit': 'µg/m³',
#     'count': 234063,
#     'average': 17.0471949859653,
#     'lastValue': 20.2,
#     'parameter': 'pm10',
#     'displayName': 'PM10',
#     'lastUpdated': '2022-03-22T02:22:35+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2022-01-20T16:29:45+00:00'},
#    {'id': 1564945,
#     'unit': 'particles/cm³',
#     'count': 234063,
#     'average': 0.895499801335538,
#     'lastValue': 0.76,
#     'parameter': 'um010',
#     'displayName': 'PM1 count',
#     'lastUpdated': '2022-03-22T02:22:35+00:00',
#     'parameterId': 126,
#     'firstUpdated': '2022-01-20T16:29:45+00:00'},
#    {'id': 1564944,
#     'unit': 'particles/cm³',
#     'count': 234063,
#     'average': 0.0017245357019264,
#     'lastValue': 0,
#     'parameter': 'um025',
#     'displayName': 'PM2.5 count',
#     'lastUpdated': '2022-03-22T02:22:35+00:00',
#     'parameterId': 130,
#     'firstUpdated': '2022-01-20T16:29:45+00:00'},
#    {'id': 1564943,
#     'unit': 'particles/cm³',
#     'count': 234063,
#     'average': 6.66487227797644e-06,
#     'lastValue': 0,
#     'parameter': 'um100',
#     'displayName': 'PM10 count',
#     'lastUpdated': '2022-03-22T02:22:35+00:00',
#     'parameterId': 135,
#     'firstUpdated': '2022-01-20T16:29:45+00:00'},
#    {'id': 1564947,
#     'unit': 'µg/m³',
#     'count': 234063,
#     'average': 15.5099550121121,
#     'lastValue': 19.3,
#     'parameter': 'pm25',
#     'displayName': 'PM2.5',
#     'lastUpdated': '2022-03-22T02:22:35+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2022-01-20T16:29:45+00:00'},
#    {'id': 1564948,
#     'unit': 'µg/m³',
#     'count': 234063,
#     'average': 8.8038963868702,
#     'lastValue': 10.1,
#     'parameter': 'pm1',
#     'displayName': 'PM1',
#     'lastUpdated': '2022-03-22T02:22:35+00:00',
#     'parameterId': 19,
#     'firstUpdated': '2022-01-20T16:29:45+00:00'}],
#   'sensorType': 'low-cost sensor',
#   'coordinates': {'latitude': 43.369232, 'longitude': 5.332426},
#   'lastUpdated': '2022-03-22T02:22:35+00:00',
#   'firstUpdated': '2022-01-20T16:29:45+00:00',
#   'measurements': 1404378},
#  {'id': 299131,
#   'name': 'Rognes',
#   'entity': 'community',
#   'country': 'FR',
#   'sources': [{'id': 'purpleair',
#     'url': 'https://www2.purpleair.com/',
#     'name': 'PurpleAir'}],
#   'isMobile': False,
#   'parameters': [{'id': 1702097,
#     'unit': 'µg/m³',
#     'count': 120654,
#     'average': 19.247381769357,
#     'lastValue': 15.4,
#     'parameter': 'pm10',
#     'displayName': 'PM10',
#     'lastUpdated': '2022-03-22T02:22:32+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2022-03-06T15:12:57+00:00'},
#    {'id': 1702102,
#     'unit': 'particles/cm³',
#     'count': 120654,
#     'average': 1.17516261375504,
#     'lastValue': 0.76,
#     'parameter': 'um010',
#     'displayName': 'PM1 count',
#     'lastUpdated': '2022-03-22T02:22:32+00:00',
#     'parameterId': 126,
#     'firstUpdated': '2022-03-06T15:12:57+00:00'},
#    {'id': 1702098,
#     'unit': 'µg/m³',
#     'count': 120654,
#     'average': 9.31680590780248,
#     'lastValue': 6.4,
#     'parameter': 'pm1',
#     'displayName': 'PM1',
#     'lastUpdated': '2022-03-22T02:22:32+00:00',
#     'parameterId': 19,
#     'firstUpdated': '2022-03-06T15:12:57+00:00'},
#    {'id': 1702099,
#     'unit': 'particles/cm³',
#     'count': 120654,
#     'average': 1.49186931224825e-05,
#     'lastValue': 0,
#     'parameter': 'um100',
#     'displayName': 'PM10 count',
#     'lastUpdated': '2022-03-22T02:22:32+00:00',
#     'parameterId': 135,
#     'firstUpdated': '2022-03-06T15:12:57+00:00'},
#    {'id': 1702100,
#     'unit': 'particles/cm³',
#     'count': 120654,
#     'average': 0.00165597493659555,
#     'lastValue': 0,
#     'parameter': 'um025',
#     'displayName': 'PM2.5 count',
#     'lastUpdated': '2022-03-22T02:22:32+00:00',
#     'parameterId': 130,
#     'firstUpdated': '2022-03-06T15:12:57+00:00'},
#    {'id': 1702101,
#     'unit': 'µg/m³',
#     'count': 120654,
#     'average': 17.363516335969,
#     'lastValue': 14.6,
#     'parameter': 'pm25',
#     'displayName': 'PM2.5',
#     'lastUpdated': '2022-03-22T02:22:32+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2022-03-06T15:12:57+00:00'}],
#   'sensorType': 'low-cost sensor',
#   'coordinates': {'latitude': 43.65449, 'longitude': 5.3793},
#   'lastUpdated': '2022-03-22T02:22:32+00:00',
#   'firstUpdated': '2022-03-06T15:12:57+00:00',
#   'measurements': 723924}]

# %% [markdown]
# 7. Print out the number of results obtained

# %%
# Out:
# 1092

# %% [markdown]
# 8. Check [this part](https://docs.openaq.org/#/v2/measurements_get_v2_measurements_get) of the documentation and identify the format that is expected from the date options to query the API.
#
# Then use `from datetime import datetime` and `from datetime import timedelta` in order to produce date 01 JAN 2022 in the API compatible format, and call it `end_date`

# %%
# Out:
# '2022-01-01T00:00:00+00:00'

# %% [markdown]
# 9. Now use `timedelta` to produce the date 10 days before in the same format, and call it `start_date`

# %%
# Out:
# '2021-12-25T00:00:00+00:00'

# %% [markdown]
# 10. Use a query to get all the data about the first location for the past day

# %% [markdown]
# 11. As you may see, a query covering 10 days for a single location already contains 46920 measures in this case. Imagine if we would like to get historical data for the prrevious ten years for the whole country, this would take some time and a lot of space, so for now just try and create a loop to get 30 days of data for the whole country.
