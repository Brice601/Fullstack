# %% [markdown]
# # Introduction to Boto3
#
# ## What you will learn in this course 🧐🧐
#
# As we are starting to cover a lot of different AWS services, you need to have a programmatic access to them instead of always using the Graphical User Interface (GUI). That is what Boto3 is all about. In this course, we will cover:
#
# * Use Boto3 to access any AWS service
# * Incorporate your AWS credentials to access your AWS account
#
# ## What is Boto3? 🤔🤔
#
# Boto3 is AWS's SDK. It will allow you to programmatically access to your AWS account and services. This is especially useful when you need to build a web app or to create ETL processes.
#
# > 🙋 **What the heck is an SDK ?!** 🙋<br/>
# > SDK stands for "Software Development Kit". This is basically a kit that provides a set of tools, librairies and documentation to help you utilize someone's service.

# %%
# Install boto3 using pip 
## Add '!' only if you install directly from a Jupyter Notebook
# !pip install Boto3
# Out:
# Requirement already satisfied: Boto3 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (1.40.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from Boto3) (1.40.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from Boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from Boto3) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from botocore<1.41.0,>=1.40.0->Boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from botocore<1.41.0,>=1.40.0->Boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/brice/anaconda3/envs/jedha/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.0->Boto3) (1.17.0)

# %% [markdown]
# ## Boto3 Basic commands 🧭🧭
#
# You will use Boto3 quite a lot throughout the whole program. You'll see that this SDK is fairly simple to use. However, Boto3 lets you use **ANY** service you need in AWS. Therefore, we'll definitely not going to cover all services that Boto3 allows you to use. Rather, we'll teach how to use basics of Boto3 and teach you how to check the documentation.
#
# ### Documentation
#
# Your best friend when you use Boto3 is **documentation** 📜! Therefore, here is the link for <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html" target="_blank">Boto3 documentation</a>.
#
# This will show you how to install Boto3 on your computer but also will give you a quickstart tutorial on how to use it.
#
# There are two main things you need to know about the documentation:
#
# - <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html" target="_blank">Quickstart</a>: it's going to make you up & running on Boto3.
# - <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/index.html" target="_blank">Available Services</a>: it's going to list you all the different AWS services that you can access to using Boto3. Once you chose the service you want to use then you can check all available functions that you can use.
#
# ### Select a resource
#
# The first thing you need to do when you are using Boto3 is to set up a session and use a given resource. You can set up a session using `boto3.Session()`.

# %%
import boto3
# session = boto3.Session(aws_access_key_id="*******", 
#                         aws_secret_access_key="*********")   # key en clair pas bonne idée.

# %%
# autre méthode pour cacher id....
# voir vidéo data storage 2h 25 m
# création fichier credentials à la racine
# créer un fichier .aws
# brice@brice-H81M-S1:~$ mkdir .aws
# brice@brice-H81M-S1:~$ mv Documents/DataScience_Jedha/Fullstack/credentials .aws/   remplacer avec le bon chemin

# si on a sauvegardé nos credentials dans ~/.aws/credentials on peut utiliser cette commande :
s3 = boto3.resource("s3")

# au lieu de session = session = boto3.Session(aws_access_key_id="******", aws_secret_access_key="*******")

# %% [markdown]
# You need to specify your own access key id & secret access key that you downloaded when you created your IAM user. If you forgot or lost your credentials. You can always do the following:

# %% [markdown]
# <div className='aspect-w-16 aspect-h-9'><iframe src='https://www.youtube.com/embed/O7ofzpnbKN8' allow='autoplay; fullscreen; picture-in-picture' allowFullScreen='' width='100%' title='Test' frameBorder='0'></iframe></div>

# %% [markdown]
# Now that you specify your session with the right credentials, you can set-up a resource. Let's take S3 for example:

# %%
# si instanciation avec Session autrement s3 = boto3.resource("s3") si on a sauvegardé dans credentials
# s3 = session.resource("s3")

# %% [markdown]
# Now you can use all the actions available that boto3 will let you do:

# %%
bucket = s3.create_bucket(Bucket="bucket-notebook-jedha-bdlp-2", CreateBucketConfiguration={"LocationConstraint": "eu-west-3"})

# %% [markdown]
# If you'd like to know more about this function 👉 check <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html#S3.ServiceResource.create_bucket" target="_blank">create_bucket</a>.

# %% [markdown]
# Here is an example of how to dump a dataframe to `.csv` file in your bucket:

# %%
import pandas as pd
data = pd.DataFrame({'col1': [1,2,3,4], 'col2': ['a1','a2','a3','a4']})
data.head()
# Out:
#    col1 col2
# 0     1   a1
# 1     2   a2
# 2     3   a3
# 3     4   a4

# %%
csv = data.to_csv()

# %%
put_object = bucket.put_object(Key="test-1.csv", Body=csv, ACL="public-read")  # paramètre ACL="public-read" pour accès public /private
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 put_object = bucket.put_object(Key="test-1.csv", Body=csv, ACL="public-read")
#
# File ~/anaconda3/envs/jedha/lib/python3.13/site-packages/boto3/resources/factory.py:581, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     580 def do_action(self, *args, **kwargs):
# --> 581     response = action(self, *args, **kwargs)
#     583     if hasattr(self, 'load'):
#     584         # Clear cached data. It will be reloaded the next
#     585         # time that an attribute is accessed.
#     586         # TODO: Make this configurable in the future?
#     587         self.meta.data = None
#
# File ~/anaconda3/envs/jedha/lib/python3.13/site-packages/boto3/resources/action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      79 params.update(kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#      92 return self._response_handler(parent, params, response)
#
# File ~/anaconda3/envs/jedha/lib/python3.13/site-packages/botocore/client.py:601, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     597     raise TypeError(
#     598         f"{py_operation_name}() only accepts keyword arguments."
#     599     )
#     600 # The "self" in this scope is referring to the BaseClient.
# --> 601 return self._make_api_call(operation_name, kwargs)
#
# File ~/anaconda3/envs/jedha/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/jedha/lib/python3.13/site-packages/botocore/client.py:1074, in BaseClient._make_api_call(self, operation_name, api_params)
#    1070     error_code = request_context.get(
#    1071         'error_code_override'
#    1072     ) or error_info.get("Code")
#    1073     error_class = self.exceptions.from_code(error_code)
# -> 1074     raise error_class(parsed_response, operation_name)
#    1075 else:
#    1076     return parsed_response
#
# ClientError: An error occurred (AccessControlListNotSupported) when calling the PutObject operation: The bucket does not allow ACLs

# %% [markdown]
# Many different methods are available to download, upload, and other functionnalities, you may find them all [here](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html).

# %%
# bucket = s3.Bucket("nom du bucket")  se connecter au bucket à supprimer
bucket.objects.all().delete()   # vider d'abord le bucket avant de le supprimer
bucket.delete()   # suppression du bucket
# Out:
# {'ResponseMetadata': {'RequestId': '8N81BP1HPSEFZD85',
#   'HostId': 'wUBJCN0Y1zlhCKgSsj0yWgWjxsx1fBjn8V7vVXJsvbrLh8++tSWjGM8aZAVnaqmGcDQ6E9xiNFw=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'wUBJCN0Y1zlhCKgSsj0yWgWjxsx1fBjn8V7vVXJsvbrLh8++tSWjGM8aZAVnaqmGcDQ6E9xiNFw=',
#    'x-amz-request-id': '8N81BP1HPSEFZD85',
#    'date': 'Fri, 01 Aug 2025 08:37:12 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Client VS Resource 💻

# %% [markdown]
# Quite often in the documentation, you will see `s3 = session.client("s3")` instead of `s3 = session.resource("s3")`
#
# This happens because there is a slight difference between the two functions. Here is a short explanation:
#
# - **Resource** : High Level API that is easier to use but will not cover 100% of what you can do with Boto3.
# - **Client** : Low-level API that will cover 100% of what you can do with Boto3, however, harder to use.
#
# If you'd like to know more, definitely check-out this [awesome answer on StackOverflow](https://stackoverflow.com/questions/42809096/difference-in-boto3-between-resource-client-and-session).

# %% [markdown]
# ## Credentials
#
# For most services, you will need boto3 to actually login to your aws account to be able to do anything.
# This guide to [Credentials with boto3](https://boto3.amazonaws.com/v1/documentation/api/latest/guide/credentials.html) will help you setup your authentication in a safe way.

# %% [markdown]
# ## Resources 📚
#
# - [Boto3 Documentation](https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html)
# - [Difference in boto3 between resource, client, and session](https://stackoverflow.com/questions/42809096/difference-in-boto3-between-resource-client-and-session)
# - [What is the difference between SDK & API](https://nordicapis.com/what-is-the-difference-between-an-api-and-an-sdk/)
