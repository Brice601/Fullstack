# %% [markdown]
# # MNIST and NN model insterpretation?
#
# In this exercise we will work with a full size version of the MNIST dataset of handwritten digits.

# %% [markdown]
# ## Model Training

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
import plotly.graph_objects as go

# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor()]) # ou PilToTensor (entier), to tensor normalise
dataset = torchvision.datasets.MNIST(root="./data", download=True, transform=transform)

# %% [markdown]
# * 1️⃣ Check out the shape of the objects you find in the dataset

# %%
dataset.data.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
dataset.targets.shape
# Out:
# torch.Size([60000])

# %% [markdown]
# * 2️⃣ Visualize one element from this dataset
# <Note type="tip" title=".squeeze">
# You may have to use a method called `.squeeze()`, checkout what it does.
# </Note>

# %%
dataset.data[0].shape
# Out:
# torch.Size([28, 28])

# %%
image, label = dataset[0]
image
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0706, 0.0706, 0.0706,
#           0.4941, 0.5333, 0.6863, 0.1020, 0.6510, 1.0000, 0.9686, 0.4980,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1176, 0.1412, 0.3686, 0.6039, 0.6667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.8824, 0.6745, 0.9922, 0.9490, 0.7647, 0.2510,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922,
#           0.9333, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9843, 0.3647, 0.3216, 0.3216, 0.2196, 0.1529, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765, 0.7137,
#           0.9686, 0.9451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3137, 0.6118, 0.4196, 0.9922, 0.9922, 0.8039, 0.0431, 0.0000,
#           0.1686, 0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0549, 0.0039, 0.6039, 0.9922, 0.3529, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.7451, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0431, 0.7451, 0.9922, 0.2745, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1373, 0.9451, 0.8824, 0.6275,
#           0.4235, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3176, 0.9412, 0.9922,
#           0.9922, 0.4667, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.7294,
#           0.9922, 0.9922, 0.5882, 0.1059, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0627,
#           0.3647, 0.9882, 0.9922, 0.7333, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.9765, 0.9922, 0.9765, 0.2510, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1804, 0.5098,
#           0.7176, 0.9922, 0.9922, 0.8118, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1529, 0.5804, 0.8980, 0.9922,
#           0.9922, 0.9922, 0.9804, 0.7137, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0941, 0.4471, 0.8667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.7882, 0.3059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0902, 0.2588, 0.8353, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765,
#           0.3176, 0.0078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.6706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.7647, 0.3137, 0.0353,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.2157, 0.6745, 0.8863, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9569, 0.5216, 0.0431, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.5333, 0.9922, 0.9922, 0.9922,
#           0.8314, 0.5294, 0.5176, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])

# %%
plt.imshow(image[0].squeeze())
plt.title(f"Label: {label}")
plt.show()

# %% [markdown]
# * 3️⃣ This data shape won't fit in a fully connected neural network, reshape the elements from the dataset so they are flat.

# %%
train_size = int(len(dataset) * 0.8)
val_size = len(dataset) - train_size
# Split dataset into training and validation
train_dataset, val_dataset = torch.utils.data.random_split(dataset=dataset, lengths=[train_size, val_size], generator=torch.Generator().manual_seed(42))

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=200)

# %%
images, labels = next(iter(train_loader))

# %% [markdown]
# * 4️⃣
#     * What is the effect of the batch size on the training of the model? If the batch size is equal to the number of observations, what would the batch gradient descent be equivalent to?
#     * With batches of 16 observations, how many times will the parameters of the model be updated before we reach one epoch?

# %% [markdown]
# * 5️⃣ Create a simple neural network model, don't forget to set an input shape in the first layer that corresponds to the data we will feed the model and define the last layer so it is able to make predictions as we expect.

# %%
class MNISTModel(nn.Module):
    def __init__(self):
        super(MNISTModel, self).__init__()
        self.fc1 = nn.Linear(in_features=784, out_features=16, bias=True)
        self.fc2 = nn.Linear(in_features=16, out_features=8, bias=True)
        self.fc3 = nn.Linear(in_features=8, out_features=10, bias=True)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
         # Flatten the input
        x = torch.flatten(x, start_dim=1)
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.softmax(self.fc3(x))
        return x

model = MNISTModel()
print(model)
# Out:
# MNISTModel(
#   (fc1): Linear(in_features=784, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=8, bias=True)
#   (fc3): Linear(in_features=8, out_features=10, bias=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# * 6️⃣ Define the Loss Function and Optimizer

# %%
labels.shape
# Out:
# torch.Size([50])

# %%
images.shape
# Out:
# torch.Size([50, 1, 28, 28])

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# * 7️⃣ Train the model on 50 epochs

# %%
import torch

def train(model, train_loader, val_loader, criterion, optimizer, epochs=100):
    """
    Function to train a PyTorch model with training and validation datasets.
    
    Parameters:
    model: The neural network model to train.
    train_loader: DataLoader for the training dataset.
    val_loader: DataLoader for the validation dataset.
    criterion: Loss function (e.g., Binary Cross Entropy for classification).
    optimizer: Optimization algorithm (e.g., Adam, SGD).
    epochs: Number of training epochs (default=100).
    
    Returns:
    history: Dictionary containing loss and accuracy for both training and validation.
    """
    
    # Dictionary to store training & validation loss and accuracy over epochs
    history = {'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}
    
    for epoch in range(epochs):  # Loop over the number of epochs
        model.train()  # Set model to training mode
        total_loss, correct = 0, 0  # Initialize total loss and correct predictions
        
        # Training loop
        for inputs, labels in train_loader:
            optimizer.zero_grad()  # Reset gradients before each batch
            outputs = model(inputs)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss
            loss.backward()  # Backpropagation (compute gradients)
            optimizer.step()  # Update model parameters
            
            total_loss += loss.item()  # Accumulate batch loss
            # Calcul de l'accuracy pour multi-classes
            _, predicted = torch.max(outputs, 1)  # Trouve la classe avec le score max
            correct += (predicted == labels).sum().item()
        
        # Compute average loss and accuracy for training
        train_loss = total_loss / len(train_loader)
        train_acc = correct / len(train_loader.dataset)
        
        # Validation phase (without gradient computation)
        model.eval()  # Set model to evaluation mode
        val_loss, val_correct = 0, 0
        with torch.no_grad():  # No need to compute gradients during validation
            for inputs, labels in val_loader:
                outputs = model(inputs)  # Forward pass
                loss = criterion(outputs, labels)  # Compute loss
                val_loss += loss.item()  # Accumulate validation loss
                # Calcul de l'accuracy pour multi-classes
                _, predicted = torch.max(outputs, 1)  # Trouve la classe avec le score max
                val_correct += (predicted == labels).sum().item()
        
        # Compute average loss and accuracy for validation
        val_loss /= len(val_loader)
        val_acc = val_correct / len(val_loader.dataset)
        
        # Store metrics in history dictionary
        history['loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['accuracy'].append(train_acc)
        history['val_accuracy'].append(val_acc)
        
        # Print training progress
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {train_loss:.4f}, Acc: {train_acc:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
    
    return history  # Return training history

# Train the model
history = train(model, train_loader, val_loader, criterion, optimizer, epochs=50)
# Out:
# Epoch [1/50], Loss: 1.6402, Acc: 0.8262, Val Loss: 1.5829, Val Acc: 0.8781
# Epoch [2/50], Loss: 1.5633, Acc: 0.8978, Val Loss: 1.5593, Val Acc: 0.9011
# Epoch [3/50], Loss: 1.5551, Acc: 0.9056, Val Loss: 1.5555, Val Acc: 0.9057
# Epoch [4/50], Loss: 1.5499, Acc: 0.9110, Val Loss: 1.5494, Val Acc: 0.9115
# Epoch [5/50], Loss: 1.5517, Acc: 0.9091, Val Loss: 1.5558, Val Acc: 0.9049
# Epoch [6/50], Loss: 1.5472, Acc: 0.9136, Val Loss: 1.5586, Val Acc: 0.9022
# Epoch [7/50], Loss: 1.5495, Acc: 0.9112, Val Loss: 1.5644, Val Acc: 0.8966
# Epoch [8/50], Loss: 1.5468, Acc: 0.9142, Val Loss: 1.5563, Val Acc: 0.9044
# Epoch [9/50], Loss: 1.5428, Acc: 0.9182, Val Loss: 1.5727, Val Acc: 0.8882
# Epoch [10/50], Loss: 1.5477, Acc: 0.9132, Val Loss: 1.5464, Val Acc: 0.9147
# Epoch [11/50], Loss: 1.5470, Acc: 0.9140, Val Loss: 1.5487, Val Acc: 0.9122
# Epoch [12/50], Loss: 1.5454, Acc: 0.9157, Val Loss: 1.5559, Val Acc: 0.9052
# Epoch [13/50], Loss: 1.5485, Acc: 0.9124, Val Loss: 1.5616, Val Acc: 0.8996
# Epoch [14/50], Loss: 1.5549, Acc: 0.9060, Val Loss: 1.5654, Val Acc: 0.8956
# Epoch [15/50], Loss: 1.5515, Acc: 0.9094, Val Loss: 1.5569, Val Acc: 0.9042
# Epoch [44/50], Loss: 1.5517, Acc: 0.9094, Val Loss: 1.5631, Val Acc: 0.8982
# Epoch [45/50], Loss: 1.5570, Acc: 0.9041, Val Loss: 1.5699, Val Acc: 0.8913
# Epoch [46/50], Loss: 1.5496, Acc: 0.9115, Val Loss: 1.5712, Val Acc: 0.8900
# Epoch [47/50], Loss: 1.5659, Acc: 0.8953, Val Loss: 1.5596, Val Acc: 0.9015
# Epoch [48/50], Loss: 1.5481, Acc: 0.9130, Val Loss: 1.5558, Val Acc: 0.9052
# Epoch [49/50], Loss: 1.5509, Acc: 0.9102, Val Loss: 1.5953, Val Acc: 0.8656
# Epoch [50/50], Loss: 1.5535, Acc: 0.9076, Val Loss: 1.5687, Val Acc: 0.8923

# %% [markdown]
# * 8️⃣ Would you say the model achieved good performance? Did it overfit?

# %% [markdown]
# ## Performance analysis
#
# * 1️⃣ Plot the evolution of the training loss and the validation loss, what do you see? What do you conclude?

# %%
plt.figure(figsize=(10,5))
plt.plot(history['loss'], label="Training Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Cross Entropy Loss")
plt.title("Training and Validatin Loss")
plt.legend()
plt.show()

# %% [markdown]
# * 2️⃣ Get the weights from the first layer

# %%
model.fc1.weight.shape
# Out:
# torch.Size([16, 784])

# %% [markdown]
# * 3️⃣ Extract the weights from one of the neurons on that layer, what does the number of weights correspond to?

# %%
model.fc1.weight[0].shape
# Out:
# torch.Size([784])

# %% [markdown]
# * 4️⃣ Reshape the weights to form a 28x28 image and display it, can you interpret the weights on this neuron?

# %%
# Reshape les poids du premier neurone en image
weights_img = model.fc1.weight[0].detach().reshape(28, 28)

plt.imshow(weights_img, cmap='gray')
plt.title("Poids du neurone 0 de fc1")
plt.colorbar()
plt.show()

# %% [markdown]
# * 5️⃣ Try the same thing with all the neurons of the first layer, can you see something interpretable? * Try the same thing with all the neurons of the first layer, can you see something interpretable? You can find help <a href="https://plotly.com/python/heatmaps/"> here </a> and <a href="https://plotly.com/python/subplots/"> here </a>.

# %%
fig, axes = plt.subplots(4, 4, figsize=(10, 10))  # Grille 4x4 pour 16 neurones

for i, ax in enumerate(axes.flat):
    if i < 16:
        # Reshape en 28x28 pour visualiser comme une image
        weights_img = model.fc1.weight[i].detach().reshape(28, 28)
        ax.imshow(weights_img, cmap='gray')
        ax.set_title(f'Neurone {i}')
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# * 6️⃣ Do the same visualization but apply relu to the weights

# %%
fig, axes = plt.subplots(4, 4, figsize=(10, 10))
for i, ax in enumerate(axes.flat):
    img = torch.nn.ReLU()(first_layer_weights[i]).view(28, 28).cpu().numpy()
    ax.imshow(img, cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 fig, axes = plt.subplots(4, 4, figsize=(10, 10))
#       2 for i, ax in enumerate(axes.flat):
# ----> 3     img = torch.nn.ReLU()(first_layer_weights[i]).view(28, 28).cpu().numpy()
#       4     ax.imshow(img, cmap='gray')
#       5     ax.axis('off')
#
# NameError: name 'first_layer_weights' is not defined

# %% [markdown]
# ## Regularization ?
#
# * 1️⃣ What can we conclude after looking at the evolution of the losses, and looking at the feature extraction from the first layer ?

# %% [markdown]
# **From looking at the training loss:**
# The evolution of the training loss indicates that the model is learning steadily on the training set, and shows stable consistent decrease.
#
# **From looking at the validation loss:**
# The evolution of the validation loss shows some instability, especially as the decrease in training loss slows down.
#
# **From looking et the feature space:**
# It seems as though only a portion of our neurons are actually learning something from our data (some neurons look like they are only capturing noise)

# %% [markdown]
# * 2️⃣ What can you do to solve this?

# %% [markdown]
# We can attempt some regularization techniques:
# * In order to stabalize the loss we can add some L2 regularization in the optimizer.
# * In order to balance out the training of our first layer we can add some drop out after that layer.

# %% [markdown]
# ### Addind Regularization
#
# 3️⃣ Train a new neural network with some L2 regularization in the optimizer, do you notice any difference?

# %%
class RegularizedNN(nn.Module):
    def __init__(self):
        super(RegularizedNN, self).__init__()
        self.fc1 = nn.Linear(in_features=784, out_features=16, bias=True)
        self.fc2 = nn.Linear(in_features=16, out_features=8, bias=True)
        self.fc3 = nn.Linear(in_features=8, out_features=10, bias=True)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)
        self.dropout = nn.Dropout(0.01)

    def forward(self, x):
         # Flatten the input
        x = torch.flatten(x, start_dim=1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.softmax(self.fc3(x))
        return x
    
model = RegularizedNN()
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.001)
train(model, train_loader, val_loader, criterion, optimizer, epochs=50)
# Out:
# Epoch [1/50], Loss: 1.6588, Acc: 0.8141, Val Loss: 1.5988, Val Acc: 0.8682
# Epoch [2/50], Loss: 1.5978, Acc: 0.8721, Val Loss: 1.5758, Val Acc: 0.8940
# Epoch [3/50], Loss: 1.5850, Acc: 0.8834, Val Loss: 1.5615, Val Acc: 0.9058
# Epoch [4/50], Loss: 1.5836, Acc: 0.8853, Val Loss: 1.5691, Val Acc: 0.8981
# Epoch [5/50], Loss: 1.5816, Acc: 0.8865, Val Loss: 1.5604, Val Acc: 0.9071
# Epoch [6/50], Loss: 1.5810, Acc: 0.8868, Val Loss: 1.5663, Val Acc: 0.9012
# Epoch [7/50], Loss: 1.5800, Acc: 0.8878, Val Loss: 1.5715, Val Acc: 0.8943
# Epoch [8/50], Loss: 1.5806, Acc: 0.8872, Val Loss: 1.5865, Val Acc: 0.8839
# Epoch [9/50], Loss: 1.5810, Acc: 0.8871, Val Loss: 1.5628, Val Acc: 0.9063
# Epoch [10/50], Loss: 1.5818, Acc: 0.8859, Val Loss: 1.5815, Val Acc: 0.8853
# Epoch [11/50], Loss: 1.5813, Acc: 0.8860, Val Loss: 1.5556, Val Acc: 0.9129
# Epoch [12/50], Loss: 1.5790, Acc: 0.8895, Val Loss: 1.5761, Val Acc: 0.8921
# Epoch [13/50], Loss: 1.5807, Acc: 0.8876, Val Loss: 1.5581, Val Acc: 0.9094
# Epoch [14/50], Loss: 1.5797, Acc: 0.8880, Val Loss: 1.5680, Val Acc: 0.9003
# Epoch [15/50], Loss: 1.5777, Acc: 0.8903, Val Loss: 1.5710, Val Acc: 0.8974
# Epoch [16/50], Loss: 1.5800, Acc: 0.8879, Val Loss: 1.5634, Val Acc: 0.9056
# Epoch [17/50], Loss: 1.5805, Acc: 0.8880, Val Loss: 1.5777, Val Acc: 0.8899
# Epoch [46/50], Loss: 1.5791, Acc: 0.8879, Val Loss: 1.5635, Val Acc: 0.9025
# Epoch [47/50], Loss: 1.5817, Acc: 0.8867, Val Loss: 1.5738, Val Acc: 0.8941
# Epoch [48/50], Loss: 1.5786, Acc: 0.8897, Val Loss: 1.5586, Val Acc: 0.9076
# Epoch [49/50], Loss: 1.5784, Acc: 0.8892, Val Loss: 1.5674, Val Acc: 0.8998
# Epoch [50/50], Loss: 1.5795, Acc: 0.8884, Val Loss: 1.5759, Val Acc: 0.8912
# {'loss': [1.6587891108045976,
#   1.5978409371028344,
#   1.5850077718496323,
#   1.5836333735535542,
#   1.5815795751909414,
#   1.5810426252583663,
#   1.5799820313851038,
#   1.5806468902776638,
#   1.5810481415440638,
#   1.5818190333743891,
#   1.5812874166915813,
#   1.5789854666839043,
#   1.5806733055661122,
#   1.579709970081846,
#   1.5777210572113594,
#   1.58001125579079,
#   1.5805433565129836,
#   1.5807554613798858,
#   1.5785244980206092,
#   1.5790962281326453,
#   1.5810682428379854,
#   1.5803352574507394,
#   1.5791840296238662,
#   1.5812997307628394,
#   1.5798559344063203,
#   1.5818044734497865,
#   1.579563601066669,
#   1.5798654110481343,
#   1.5798311633368334,
#   1.5815706092864275,
#   1.5795548082639774,
#   1.5780526811877886,
#   1.5805360121031602,
#   1.5793750803917646,
#   1.577332279831171,
#   1.5797618857274454,
#   1.5777961784352859,
#   1.5790886618196964,
#   1.5774300480882326,
#   1.5786569101115069,
#   1.580168539037307,
#   1.578813911229372,
#   1.5791978600124519,
#   1.5794603562603393,
#   1.5791204892098905,
#   1.5791310865432024,
#   1.5816635868201654,
#   1.5786164358258248,
#   1.5784264493733644,
#   1.5795293328662714],
#  'val_loss': [1.5988221367200215,
#   1.575789084037145,
#   1.5614896615346272,
#   1.5691148400306703,
#   1.5604254523913066,
#   1.566284724076589,
#   1.5714994370937347,
#   1.586472511291504,
#   1.5627768297990163,
#   1.5815409441788992,
#   1.555576499303182,
#   1.5761412918567657,
#   1.5581375539302826,
#   1.5679910679658253,
#   1.5709502339363097,
#   1.563405301173528,
#   1.577702267964681,
#   1.5609195371468862,
#   1.5591646512349446,
#   1.5688167572021485,
#   1.5880017817020415,
#   1.5694019794464111,
#   1.5578415592511494,
#   1.5574117700258892,
#   1.573023889462153,
#   1.568283478418986,
#   1.5820547918478647,
#   1.5730669319629669,
#   1.57568971713384,
#   1.5655214051405588,
#   1.5697150687376658,
#   1.5712537248929341,
#   1.5618202567100525,
#   1.56036163965861,
#   1.5704900979995728,
#   1.5613790114720663,
#   1.5736990531285604,
#   1.5612586617469788,
#   1.5824792484442394,
#   1.5587440073490142,
#   1.5759846727053324,
#   1.5607928196589151,
#   1.5956613838672637,
#   1.5779311160246532,
#   1.5741727292537688,
#   1.5634624759356182,
#   1.5737902502218881,
#   1.55858300725619,
#   1.5673737982908884,
#   1.5758747398853301],
#  'accuracy': [0.8141458333333333,
#   0.8721458333333333,
#   0.8833958333333334,
#   0.8852916666666667,
#   0.8864583333333333,
#   0.88675,
#   0.88775,
#   0.8872291666666666,
#   0.887125,
#   0.885875,
#   0.8860208333333334,
#   0.8895416666666667,
#   0.8875625,
#   0.8879791666666667,
#   0.8903125,
#   0.8878541666666667,
#   0.8879583333333333,
#   0.8872916666666667,
#   0.8895833333333333,
#   0.8893541666666667,
#   0.8870416666666666,
#   0.8879166666666667,
#   0.889375,
#   0.8863333333333333,
#   0.8882916666666667,
#   0.8860833333333333,
#   0.8882916666666667,
#   0.8881041666666667,
#   0.888625,
#   0.8863541666666667,
#   0.8886666666666667,
#   0.8906875,
#   0.8876875,
#   0.8884791666666667,
#   0.8908125,
#   0.8883333333333333,
#   0.8901666666666667,
#   0.8893125,
#   0.8902708333333333,
#   0.8898541666666666,
#   0.8878125,
#   0.8897291666666667,
#   0.889125,
#   0.8884583333333333,
#   0.8896458333333334,
#   0.8878958333333333,
#   0.8867291666666667,
#   0.8896875,
#   0.8892291666666666,
#   0.8884375],
#  'val_accuracy': [0.86825,
#   0.894,
#   0.90575,
#   0.8980833333333333,
#   0.9070833333333334,
#   0.9011666666666667,
#   0.8943333333333333,
#   0.8839166666666667,
#   0.9063333333333333,
#   0.8853333333333333,
#   0.9129166666666667,
#   0.8920833333333333,
#   0.9094166666666667,
#   0.9003333333333333,
#   0.8974166666666666,
#   0.9055833333333333,
#   0.8899166666666667,
#   0.9048333333333334,
#   0.91075,
#   0.8993333333333333,
#   0.878,
#   0.89725,
#   0.9081666666666667,
#   0.9111666666666667,
#   0.8931666666666667,
#   0.90075,
#   0.8865,
#   0.8956666666666667,
#   0.8930833333333333,
#   0.9004166666666666,
#   0.89775,
#   0.8970833333333333,
#   0.90525,
#   0.907,
#   0.89775,
#   0.9060833333333334,
#   0.8949166666666667,
#   0.9055,
#   0.8856666666666667,
#   0.90625,
#   0.8923333333333333,
#   0.9078333333333334,
#   0.87325,
#   0.8931666666666667,
#   0.8945833333333333,
#   0.9025,
#   0.8940833333333333,
#   0.9075833333333333,
#   0.89975,
#   0.8911666666666667]}

# %%
plt.figure(figsize=(10,5))
plt.plot(history['loss'], label="Training Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Cross Entropy Loss")
plt.title("Training and Validatin Loss")
plt.legend()
plt.show()

# %%
model.fc1.weight.shape
# Out:
# torch.Size([16, 784])

# %%
fig, axes = plt.subplots(4, 4, figsize=(10, 10))  # Grille 4x4 pour 16 neurones

for i, ax in enumerate(axes.flat):
    if i < 16:
        # Reshape en 28x28 pour visualiser comme une image
        weights_img = model.fc1.weight[i].detach().reshape(28, 28)
        ax.imshow(weights_img, cmap='gray')
        ax.set_title(f'Neurone {i}')
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# After adding regularization, all neurons on the first layer seem to be training, however some of them seem to focus on very specific cases.

# %% [markdown]
# ### Adding DropOut
#
# 4️⃣ Now that we have tried regulaization, let's attempt some dropout after the first layer and see how it goes:

# %%
class MNISTModelDropOut(nn.Module):
    def __init__(self):
       

    def forward(self, x):
  # Flatten the input

model_dropout = MNISTModelDropOut()
print(model_dropout)


# add L2 regularization with weight decay

# Train the model
# Out:
# MNISTModelDropOut(
#   (fc1): Linear(in_features=784, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=8, bias=True)
#   (fc3): Linear(in_features=8, out_features
# Epoch [27/50], Loss: 1.6391, Acc: 0.8299, Val Loss: 1.5725, Val Acc: 0.8939
# Epoch [28/50], Loss: 1.6359, Acc: 0.8338, Val Loss: 1.5721, Val Acc: 0.8929
# Epoch [29/50], Loss: 1.6346, Acc: 0.8356, Val Loss: 1.5628, Val Acc: 0.9041
# Epoch [30/50], Loss: 1.6341, Acc: 0.8358, Val Loss: 1.5753, Val Acc: 0.8890
# Epoch [31/50], Loss: 1.6332, Acc: 0.8354, Val Loss: 1.5950, Val Acc: 0.8685
# Epoch [32/50], Loss: 1.6365, Acc: 0.8326, Val Loss: 1.5683, Val Acc: 0.8982
# Epoch [33/50], Loss: 1.6341, Acc: 0.8359, Val Loss: 1.5663, Val Acc: 0.8998
# Epoch [34/50], Loss: 1.6312, Acc: 0.8391, Val Loss: 1.5673, Val Acc: 0.8978
# Epoch [35/50], Loss: 1.6322, Acc: 0.8371, Val Loss: 1.5735, Val Acc: 0.8932
# Epoch [36/50], Loss: 1.6317, Acc: 0.8383, Val Loss: 1.5637, Val Acc: 0.9032
# Epoch [37/50], Loss: 1.6346, Acc: 0.8343, Val Loss: 1.5723, Val Acc: 0.8952
# Epoch [38/50], Loss: 1.6311, Acc: 0.8383, Val Loss: 1.5783, Val Acc: 0.8875
# Epoch [39/50], Loss: 1.6317, Acc: 0.8380, Val Loss: 1.5718, Val Acc: 0.8952
# Epoch [40/50], Loss: 1.6313, Acc: 0.8390, Val Loss: 1.5652, Val Acc: 0.9008
# Epoch [41/50], Loss: 1.6337, Acc: 0.8356, Val Loss: 1.5746, Val Acc: 0.8928
# Epoch [42/50], Loss: 1.6326, Acc: 0.8356, Val Loss: 1.5724, Val Acc: 0.8955
# Epoch [43/50], Loss: 1.6318, Acc: 0.8383, Val Loss: 1.5649, Val Acc: 0.9017
# Epoch [44/50], Loss: 1.6321, Acc: 0.8355, Val Loss: 1.5707, Val Acc: 0.8942
# Epoch [45/50], Loss: 1.6329, Acc: 0.8363, Val Loss: 1.5644, Val Acc: 0.9031
# Epoch [46/50], Loss: 1.6306, Acc: 0.8381, Val Loss: 1.5719, Val Acc: 0.8940
# Epoch [47/50], Loss: 1.6296, Acc: 0.8397, Val Loss: 1.5712, Val Acc: 0.8957
# Epoch [48/50], Loss: 1.6313, Acc: 0.8386, Val Loss: 1.5838, Val Acc: 0.8830
# Epoch [49/50], Loss: 1.6299, Acc: 0.8388, Val Loss: 1.5676, Val Acc: 0.8984
# Epoch [50/50], Loss: 1.6300, Acc: 0.8388, Val Loss: 1.5644, Val Acc: 0.9028

# %% [markdown]
# Adding dropout increases the training loss because dropout is in effect during training and blocks part of the information flow from reaching the other neurons.
#
# However there does not seem to be any negative effect on the validation loss.

# %%
# Out:
# torch.Size([16, 784])

# %% [markdown]
# In terms of feature extraction in the first layer, it seems that drop out helped even things out across neurons.

# %% [markdown]
# ## Conclusion
#
# Analyzing the first-layer weights helps us understand what patterns the model is learning from the MNIST images. While it’s not as intuitive as human perception, it provides insights into feature extraction in neural networks.
