# %% [markdown]
# # CalTech 101
#
# Now that we have learned how to do Transfer Learning, let's try to use it on larger Datasets. We will study the [CalTech101] dataset (http://www.vision.caltech.edu/Image_Datasets/Caltech101/) which contains 40 to 800 images from 101 categories.

# %% [markdown]
# 1. Import the classic librairies

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms.v2 as transforms
import torchvision.datasets as datasets
from torchvision import models
from torch.utils.data import DataLoader
import shutil
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# 2. Using [`datasets.Caltech101`](https://pytorch.org/vision/main/generated/torchvision.datasets.Caltech101.html), download and extract the Caltech101 dataset.

# %%
# telecharger en tgz sur https://data.caltech.edu/records/mzrjq-6wc02

# %%
data_root = Path("caltech-101/101_ObjectCategories/")
for item in data_root.iterdir():
  print(item)
# Out:
# caltech-101\101_ObjectCategories\accordion
# caltech-101\101_ObjectCategories\airplanes
# caltech-101\101_ObjectCategories\anchor
# caltech-101\101_ObjectCategories\ant
# caltech-101\101_ObjectCategories\BACKGROUND_Google
# caltech-101\101_ObjectCategories\barrel
# caltech-101\101_ObjectCategories\bass
# caltech-101\101_ObjectCategories\beaver
# caltech-101\101_ObjectCategories\binocular
# caltech-101\101_ObjectCategories\bonsai
# caltech-101\101_ObjectCategories\brain
# caltech-101\101_ObjectCategories\brontosaurus
# caltech-101\101_ObjectCategories\buddha
# caltech-101\101_ObjectCategories\butterfly
# caltech-101\101_ObjectCategories\camera
# caltech-101\101_ObjectCategories\cannon
# caltech-101\101_ObjectCategories\car_side
# caltech-101\101_ObjectCategories\ceiling_fan
# caltech-101\101_ObjectCategories\cellphone
# caltech-101\101_ObjectCategories\chair
# caltech-101\101_ObjectCategories\chandelier
# caltech-101\101_ObjectCategories\cougar_body
# caltech-101\101_ObjectCategories\cougar_face
# caltech-101\101_ObjectCategories\crab
# caltech-101\101_ObjectCategories\crayfish
# caltech-101\101_ObjectCategories\crocodile
# caltech-101\101_ObjectCategories\crocodile_head
# caltech-101\101_ObjectCategories\cup
# caltech-101\101_ObjectCategories\dalmatian
# caltech-101\101_ObjectCategories\dollar_bill
# caltech-101\101_ObjectCategories\dolphin
# caltech-101\101_ObjectCategories\dragonfly
# caltech-101\101_ObjectCategories\electric_guitar
# caltech-101\101_ObjectCategories\elephant
# caltech-101\101_ObjectCategories\emu
# caltech-101\101_ObjectCategories\euphonium
# caltech-101\101_ObjectCategories\ewer
# caltech-101\101_ObjectCategories\Faces
# caltech-101\101_ObjectCategories\Faces_easy
# caltech-101\101_ObjectCategories\ferry
# caltech-101\101_ObjectCategories\flamingo
# caltech-101\101_ObjectCategories\flamingo_head
# caltech-101\101_ObjectCategories\garfield
# caltech-101\101_ObjectCategories\gerenuk
# caltech-101\101_ObjectCategories\gramophone
# caltech-101\101_ObjectCategories\grand_piano
# caltech-101\101_ObjectCategories\hawksbill
# caltech-101\101_ObjectCategories\headphone
# caltech-101\101_ObjectCategories\hedgehog
# caltech-101\101_ObjectCategories\helicopter
# caltech-101\101_ObjectCategories\ibis
# caltech-101\101_ObjectCategories\inline_skate
# caltech-101\101_ObjectCategories\joshua_tree
# caltech-101\101_ObjectCategories\kangaroo
# caltech-101\101_ObjectCategories\ketch
# caltech-101\101_ObjectCategories\lamp
# caltech-101\101_ObjectCategories\laptop
# caltech-101\101_ObjectCategories\Leopards
# caltech-101\101_ObjectCategories\llama
# caltech-101\101_ObjectCategories\lobster
# caltech-101\101_ObjectCategories\lotus
# caltech-101\101_ObjectCategories\mandolin
# caltech-101\101_ObjectCategories\mayfly
# caltech-101\101_ObjectCategories\menorah
# caltech-101\101_ObjectCategories\metronome
# caltech-101\101_ObjectCategories\minaret
# caltech-101\101_ObjectCategories\Motorbikes
# caltech-101\101_ObjectCategories\nautilus
# caltech-101\101_ObjectCategories\octopus
# caltech-101\101_ObjectCategories\okapi
# caltech-101\101_ObjectCategories\pagoda
# caltech-101\101_ObjectCategories\panda
# caltech-101\101_ObjectCategories\pigeon
# caltech-101\101_ObjectCategories\pizza
# caltech-101\101_ObjectCategories\platypus
# caltech-101\101_ObjectCategories\pyramid
# caltech-101\101_ObjectCategories\revolver
# caltech-101\101_ObjectCategories\rhino
# caltech-101\101_ObjectCategories\rooster
# caltech-101\101_ObjectCategories\saxophone
# caltech-101\101_ObjectCategories\schooner
# caltech-101\101_ObjectCategories\scissors
# caltech-101\101_ObjectCategories\scorpion
# caltech-101\101_ObjectCategories\sea_horse
# caltech-101\101_ObjectCategories\snoopy
# caltech-101\101_ObjectCategories\soccer_ball
# caltech-101\101_ObjectCategories\stapler
# caltech-101\101_ObjectCategories\starfish
# caltech-101\101_ObjectCategories\stegosaurus
# caltech-101\101_ObjectCategories\stop_sign
# caltech-101\101_ObjectCategories\strawberry
# caltech-101\101_ObjectCategories\sunflower
# caltech-101\101_ObjectCategories\tick
# caltech-101\101_ObjectCategories\trilobite
# caltech-101\101_ObjectCategories\umbrella
# caltech-101\101_ObjectCategories\watch
# caltech-101\101_ObjectCategories\water_lilly
# caltech-101\101_ObjectCategories\wheelchair
# caltech-101\101_ObjectCategories\wild_cat
# caltech-101\101_ObjectCategories\windsor_chair
# caltech-101\101_ObjectCategories\wrench
# caltech-101\101_ObjectCategories\yin_yang

# %% [markdown]
# # Data Augmentation
#
# We will now proceed to the preprocessing of our data. The easiest way to do so is using a composition of several transform functions from `torchvision.transforms.v2`.
# The target shapes of our images should be `(299,299)`.

# %%
# Define transformations for data augmentation and normalization

    # Make sure images are converted to RGB format with 3 channels even if they are originally in grayscale

    # Randomly flip the image horizontally (left-right) with a probability of 50%

    # Randomly flip the image vertically (up-down) with a probability of 50%

    # Randomly adjust brightness and contrast (±20% variation)

    # Resize the image to match the required input size for models like InceptionV3 (299x299 pixels)

    # Convert the image to a PyTorch tensor (channels-first format: C x H x W)

    # Normalize pixel values to range [-1, 1] using mean and standard deviation.
    # This helps improve model stability and training efficiency.

# Define transformations for data augmentation
transform = transforms.Compose([
    transforms.Lambda(lambda img: img.convert('RGB')),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# c:\Users\briic\anaconda3\envs\pytorch\lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %% [markdown]
# 2. Prepare two objects `train_loader` and `val_loader` using the `datasets.ImageFolder` class.
# Form batches of 32 images, make sure you use an option to drop the last batch as you may run into trouble if the last bactch contains only one image. (You may leave the drop_last argument blank, and witness the thick opacity of the error message you'll get 🤭)

# %%
# Load dataset using ImageFolder
dataset = datasets.ImageFolder(root=data_root, transform=transform)
# Load image from the folder unsing image folder
image, label = dataset[1000]
# split data into train and validation set
train_size = int(0.7 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
# Create the data loaders for the train set and validation set
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# 3. Visualize a batch of images coming from the train set. Do you notice anyhting we will have to take into consideration when building the model?

# %%
# Get class names
class_names = dataset.classes

# loop through a batch of images to plot them
imgs, labels = next(iter(train_loader))
for i, (img, label) in enumerate(zip(imgs, labels)):
  true_label_name = class_names[label]
  print("Label :", true_label_name)
  plt.imshow(img.permute(1, 2, 0).numpy())
  plt.show()
  if i==9: break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.0822659].
# Label : schooner
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Label : Motorbikes
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.6555357..2.0125492].
# Label : BACKGROUND_Google
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.186841].
# Label : dragonfly
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Label : Faces
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Label : octopus
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9980307..2.2739873].
# Label : pagoda
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5699118..2.3785625].
# Label : dragonfly
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8781512..2.5877128].
# Label : Faces_easy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Label : platypus

# %% [markdown]
# # Transfer Learning
#
# 1. Import a pretrained model from tensorflow, the solution will use the example of <a href="https://pytorch.org/vision/main/models/generated/torchvision.models.inception_v3.html"> InceptionV3 </a>, but feel free to use different architecture if you would like to get a different point of view. Make sure you use the pretrained weights from `imagenet`.

# %%
# Load a pre-trained model (Inception v3) with imagenet weights
model = models.inception_v3(weights="IMAGENET1K_V1")

# %%
print(model)
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
from torchinfo import summary

# Print model summary
summary(model, input_size=(1, 3, 299, 299))  # (batch_size, input_features)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Inception3                               [1, 1000]                 3,326,696
# ├─BasicConv2d: 1-1                       [1, 32, 149, 149]         --
# │    └─Conv2d: 2-1                       [1, 32, 149, 149]         864
# │    └─BatchNorm2d: 2-2                  [1, 32, 149, 149]         64
# ├─BasicConv2d: 1-2                       [1, 32, 147, 147]         --
# │    └─Conv2d: 2-3                       [1, 32, 147, 147]         9,216
# │    └─BatchNorm2d: 2-4                  [1, 32, 147, 147]         64
# ├─BasicConv2d: 1-3                       [1, 64, 147, 147]         --
# │    └─Conv2d: 2-5                       [1, 64, 147, 147]         18,432
# │    └─BatchNorm2d: 2-6                  [1, 64, 147, 147]         128
# ├─MaxPool2d: 1-4                         [1, 64, 73, 73]           --
# ├─BasicConv2d: 1-5                       [1, 80, 73, 73]           --
# │    └─Conv2d: 2-7                       [1, 80, 73, 73]           5,120
# │    └─BatchNorm2d: 2-8                  [1, 80, 73, 73]           160
# ├─BasicConv2d: 1-6                       [1, 192, 71, 71]          --
# │    └─Conv2d: 2-9                       [1, 192, 71, 71]          138,240
# │    └─BatchNorm2d: 2-10                 [1, 192, 71, 71]          384
# ├─MaxPool2d: 1-7                         [1, 192, 35, 35]          --
# ├─InceptionA: 1-8                        [1, 256, 35, 35]          --
# │    └─BasicConv2d: 2-11                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-1                  [1, 64, 35, 35]           12,288
# │    │    └─BatchNorm2d: 3-2             [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-12                 [1, 48, 35, 35]           --
# │    │    └─Conv2d: 3-3                  [1, 48, 35, 35]           9,216
# │    │    └─BatchNorm2d: 3-4             [1, 48, 35, 35]           96
# │    └─BasicConv2d: 2-13                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-5                  [1, 64, 35, 35]           76,800
# │    │    └─BatchNorm2d: 3-6             [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-14                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-7                  [1, 64, 35, 35]           12,288
# │    │    └─BatchNorm2d: 3-8             [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-15                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-9                  [1, 96, 35, 35]           55,296
# │    │    └─BatchNorm2d: 3-10            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-16                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-11                 [1, 96, 35, 35]           82,944
# │    │    └─BatchNorm2d: 3-12            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-17                 [1, 32, 35, 35]           --
# │    │    └─Conv2d: 3-13                 [1, 32, 35, 35]           6,144
# │    │    └─BatchNorm2d: 3-14            [1, 32, 35, 35]           64
# ├─InceptionA: 1-9                        [1, 288, 35, 35]          --
# │    └─BasicConv2d: 2-18                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-15                 [1, 64, 35, 35]           16,384
# │    │    └─BatchNorm2d: 3-16            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-19                 [1, 48, 35, 35]           --
# │    │    └─Conv2d: 3-17                 [1, 48, 35, 35]           12,288
# │    │    └─BatchNorm2d: 3-18            [1, 48, 35, 35]           96
# │    └─BasicConv2d: 2-20                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-19                 [1, 64, 35, 35]           76,800
# │    │    └─BatchNorm2d: 3-20            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-21                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-21                 [1, 64, 35, 35]           16,384
# │    │    └─BatchNorm2d: 3-22            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-22                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-23                 [1, 96, 35, 35]           55,296
# │    │    └─BatchNorm2d: 3-24            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-23                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-25                 [1, 96, 35, 35]           82,944
# │    │    └─BatchNorm2d: 3-26            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-24                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-27                 [1, 64, 35, 35]           16,384
# │    │    └─BatchNorm2d: 3-28            [1, 64, 35, 35]           128
# ├─InceptionA: 1-10                       [1, 288, 35, 35]          --
# │    └─BasicConv2d: 2-25                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-29                 [1, 64, 35, 35]           18,432
# │    │    └─BatchNorm2d: 3-30            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-26                 [1, 48, 35, 35]           --
# │    │    └─Conv2d: 3-31                 [1, 48, 35, 35]           13,824
# │    │    └─BatchNorm2d: 3-32            [1, 48, 35, 35]           96
# │    └─BasicConv2d: 2-27                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-33                 [1, 64, 35, 35]           76,800
# │    │    └─BatchNorm2d: 3-34            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-28                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-35                 [1, 64, 35, 35]           18,432
# │    │    └─BatchNorm2d: 3-36            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-29                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-37                 [1, 96, 35, 35]           55,296
# │    │    └─BatchNorm2d: 3-38            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-30                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-39                 [1, 96, 35, 35]           82,944
# │    │    └─BatchNorm2d: 3-40            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-31                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-41                 [1, 64, 35, 35]           18,432
# │    │    └─BatchNorm2d: 3-42            [1, 64, 35, 35]           128
# ├─InceptionB: 1-11                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-32                 [1, 384, 17, 17]          --
# │    │    └─Conv2d: 3-43                 [1, 384, 17, 17]          995,328
# │    │    └─BatchNorm2d: 3-44            [1, 384, 17, 17]          768
# │    └─BasicConv2d: 2-33                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-45                 [1, 64, 35, 35]           18,432
# │    │    └─BatchNorm2d: 3-46            [1, 64, 35, 35]           128
# │    └─BasicConv2d: 2-34                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-47                 [1, 96, 35, 35]           55,296
# │    │    └─BatchNorm2d: 3-48            [1, 96, 35, 35]           192
# │    └─BasicConv2d: 2-35                 [1, 96, 17, 17]           --
# │    │    └─Conv2d: 3-49                 [1, 96, 17, 17]           82,944
# │    │    └─BatchNorm2d: 3-50            [1, 96, 17, 17]           192
# ├─InceptionC: 1-12                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-36                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-51                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-52            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-37                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-53                 [1, 128, 17, 17]          98,304
# │    │    └─BatchNorm2d: 3-54            [1, 128, 17, 17]          256
# │    └─BasicConv2d: 2-38                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-55                 [1, 128, 17, 17]          114,688
# │    │    └─BatchNorm2d: 3-56            [1, 128, 17, 17]          256
# │    └─BasicConv2d: 2-39                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-57                 [1, 192, 17, 17]          172,032
# │    │    └─BatchNorm2d: 3-58            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-40                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-59                 [1, 128, 17, 17]          98,304
# │    │    └─BatchNorm2d: 3-60            [1, 128, 17, 17]          256
# │    └─BasicConv2d: 2-41                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-61                 [1, 128, 17, 17]          114,688
# │    │    └─BatchNorm2d: 3-62            [1, 128, 17, 17]          256
# │    └─BasicConv2d: 2-42                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-63                 [1, 128, 17, 17]          114,688
# │    │    └─BatchNorm2d: 3-64            [1, 128, 17, 17]          256
# │    └─BasicConv2d: 2-43                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-65                 [1, 128, 17, 17]          114,688
# │    │    └─BatchNorm2d: 3-66            [1, 128, 17, 17]          256
# │    └─BasicConv2d: 2-44                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-67                 [1, 192, 17, 17]          172,032
# │    │    └─BatchNorm2d: 3-68            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-45                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-69                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-70            [1, 192, 17, 17]          384
# ├─InceptionC: 1-13                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-46                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-71                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-72            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-47                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-73                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-74            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-48                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-75                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-76            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-49                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-77                 [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-78            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-50                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-79                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-80            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-51                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-81                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-82            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-52                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-83                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-84            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-53                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-85                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-86            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-54                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-87                 [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-88            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-55                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-89                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-90            [1, 192, 17, 17]          384
# ├─InceptionC: 1-14                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-56                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-91                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-92            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-57                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-93                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-94            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-58                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-95                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-96            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-59                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-97                 [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-98            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-60                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-99                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-100           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-61                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-101                [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-102           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-62                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-103                [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-104           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-63                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-105                [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-106           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-64                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-107                [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-108           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-65                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-109                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-110           [1, 192, 17, 17]          384
# ├─InceptionC: 1-15                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-66                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-111                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-112           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-67                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-113                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-114           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-68                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-115                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-116           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-69                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-117                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-118           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-70                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-119                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-120           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-71                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-121                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-122           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-72                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-123                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-124           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-73                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-125                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-126           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-74                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-127                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-128           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-75                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-129                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-130           [1, 192, 17, 17]          384
# ├─InceptionD: 1-16                       [1, 1280, 8, 8]           --
# │    └─BasicConv2d: 2-76                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-131                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-132           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-77                 [1, 320, 8, 8]            --
# │    │    └─Conv2d: 3-133                [1, 320, 8, 8]            552,960
# │    │    └─BatchNorm2d: 3-134           [1, 320, 8, 8]            640
# │    └─BasicConv2d: 2-78                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-135                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-136           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-79                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-137                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-138           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-80                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-139                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-140           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-81                 [1, 192, 8, 8]            --
# │    │    └─Conv2d: 3-141                [1, 192, 8, 8]            331,776
# │    │    └─BatchNorm2d: 3-142           [1, 192, 8, 8]            384
# ├─InceptionE: 1-17                       [1, 2048, 8, 8]           --
# │    └─BasicConv2d: 2-82                 [1, 320, 8, 8]            --
# │    │    └─Conv2d: 3-143                [1, 320, 8, 8]            409,600
# │    │    └─BatchNorm2d: 3-144           [1, 320, 8, 8]            640
# │    └─BasicConv2d: 2-83                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-145                [1, 384, 8, 8]            491,520
# │    │    └─BatchNorm2d: 3-146           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-84                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-147                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-148           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-85                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-149                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-150           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-86                 [1, 448, 8, 8]            --
# │    │    └─Conv2d: 3-151                [1, 448, 8, 8]            573,440
# │    │    └─BatchNorm2d: 3-152           [1, 448, 8, 8]            896
# │    └─BasicConv2d: 2-87                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-153                [1, 384, 8, 8]            1,548,288
# │    │    └─BatchNorm2d: 3-154           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-88                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-155                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-156           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-89                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-157                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-158           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-90                 [1, 192, 8, 8]            --
# │    │    └─Conv2d: 3-159                [1, 192, 8, 8]            245,760
# │    │    └─BatchNorm2d: 3-160           [1, 192, 8, 8]            384
# ├─InceptionE: 1-18                       [1, 2048, 8, 8]           --
# │    └─BasicConv2d: 2-91                 [1, 320, 8, 8]            --
# │    │    └─Conv2d: 3-161                [1, 320, 8, 8]            655,360
# │    │    └─BatchNorm2d: 3-162           [1, 320, 8, 8]            640
# │    └─BasicConv2d: 2-92                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-163                [1, 384, 8, 8]            786,432
# │    │    └─BatchNorm2d: 3-164           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-93                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-165                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-166           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-94                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-167                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-168           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-95                 [1, 448, 8, 8]            --
# │    │    └─Conv2d: 3-169                [1, 448, 8, 8]            917,504
# │    │    └─BatchNorm2d: 3-170           [1, 448, 8, 8]            896
# │    └─BasicConv2d: 2-96                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-171                [1, 384, 8, 8]            1,548,288
# │    │    └─BatchNorm2d: 3-172           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-97                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-173                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-174           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-98                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-175                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-176           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-99                 [1, 192, 8, 8]            --
# │    │    └─Conv2d: 3-177                [1, 192, 8, 8]            393,216
# │    │    └─BatchNorm2d: 3-178           [1, 192, 8, 8]            384
# ├─AdaptiveAvgPool2d: 1-19                [1, 2048, 1, 1]           --
# ├─Dropout: 1-20                          [1, 2048, 1, 1]           --
# ├─Linear: 1-21                           [1, 1000]                 2,049,000
# ==========================================================================================
# Total params: 27,161,264
# Trainable params: 27,161,264
# Non-trainable params: 0
# Total mult-adds (G): 5.71
# ==========================================================================================
# Input size (MB): 1.07
# Forward/backward pass size (MB): 143.49
# Params size (MB): 95.34
# Estimated Total Size (MB): 239.90
# ==========================================================================================

# %% [markdown]
# 2. Set the weights of your imported model as non-trainable

# %%
# Freeze the feature extraction layers
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# 3. Create now your complete model by adding the last layer adapted to your situation

# %%
# Modify the final classification layer to match the number of classes
 # fully connected layer with num_classes neurons
 # Softmax activation for classification
num_classes = len(train_dataset.dataset.classes)
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, num_classes),
    #nn.Softmax(dim=1) Pas de Softmax ! CrossEntropyLoss s'en occupe
)

# %%
model.to(device)
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=102, bias=True)
#   )
# )

# %% [markdown]
# 4. Compile your model with [`compile`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) using Adam with a learning rate of `0.001` and the appropriate loss and metrics.

# %%
# Define loss function and optimizer
  # Move loss function to device
criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)  # Move loss function to MPS

optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %% [markdown]
# 5. Train your model and monitor the overfitting using the validation data for 5 epochs.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

# Training function for a PyTorch model
# This function is responsible for training a neural network and evaluating it on a validation set.

# Parameters:
# - model: The neural network model to be trained.
# - train_loader: DataLoader for the training dataset.
# - val_loader: DataLoader for the validation dataset.
# - criterion: Loss function (e.g., CrossEntropyLoss for classification).
# - optimizer: Optimization algorithm (e.g., Adam, SGD).
# - epochs: Number of training epochs (default = 50).

# Returns:
# - history: Dictionary containing loss and accuracy for both training and validation.

# Dictionary to store loss and accuracy values for each epoch.

# Loop through the specified number of epochs.

# Set model to training mode.

# Initialize loss and correct predictions.

# Training loop - iterate through batches in the training set.

# Move inputs and labels to the same device as the model.

# Reset gradients before each batch.

# Forward pass: Get predictions from the model.

# Compute loss using the criterion.

# Backpropagation: Compute gradients.

# Update model parameters using the optimizer.

# Accumulate total loss.

# Count correct predictions.

# Compute average loss and accuracy for the training set.

# Validation phase (no gradient calculation needed).

# Set model to evaluation mode.

# Disable gradient calculation for efficiency.

# Iterate through the validation set.

# Skip iteration if batch size is 1 (to avoid issues with certain models).

# Move inputs and labels to the same device as the model.

# Forward pass to get predictions.

# Extract predictions from logits.

# Compute validation loss.

# Accumulate validation loss.

# Count correct predictions.

# Compute average loss and accuracy for the validation set.

# Store training and validation metrics for analysis.

# Print progress after each epoch.

# Return training history for later analysis.


def train(model, train_loader, val_loader, criterion, optimizer, epochs=50):
    """
    Function to train a PyTorch model and evaluate it on a validation set.

    Parameters:
    - model: The neural network model to be trained.
    - train_loader: DataLoader for the training dataset.
    - val_loader: DataLoader for the validation dataset.
    - criterion: Loss function (e.g., CrossEntropyLoss for classification).
    - optimizer: Optimization algorithm (e.g., Adam, SGD).
    - epochs: Number of training epochs (default = 50).

    Returns:
    - history: Dictionary containing loss and accuracy for both training and validation.
    """

    # Dictionary to store loss and accuracy values for each epoch
    history = {'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}
    
    # Loop through the specified number of epochs
    for epoch in range(epochs):
        model.train()  # Set model to training mode
        total_loss, correct = 0, 0  # Initialize loss and correct predictions
        
        # Training loop - iterate through batches in the training set
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()  # Reset gradients before each batch
            logit, aux_logit = model(inputs)  # Forward pass: Get predictions
            loss = criterion(logit, labels)  # Compute loss
            loss.backward()  # Backpropagation: Compute gradients
            optimizer.step()  # Update model parameters using optimizer
            
            total_loss += loss.item()  # Accumulate total loss
            correct += (logit.argmax(dim=1) == labels.data).sum().item()  # Count correct predictions
        
        # Compute average loss and accuracy for the training set
        train_loss = total_loss / len(train_loader)
        train_acc = correct / len(train_loader.dataset)
        
        # Validation phase (no gradient calculation needed)
        model.eval()  # Set model to evaluation mode
        val_loss, val_correct = 0, 0
        with torch.no_grad():  # Disable gradient calculation for efficiency
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                logit = model(inputs)  # Forward pass
                _, preds = torch.max(logit, 1) # extract predictions
                loss = criterion(logit, labels.data)  # Compute validation loss
                val_loss += loss.item()  # Accumulate validation loss
                val_correct += (logit.argmax(dim=1) == labels.data).sum().item()  # Count correct predictions
        
        # Compute average loss and accuracy for the validation set
        val_loss /= len(val_loader)
        val_acc = val_correct / len(val_loader.dataset)
        
        # Store training and validation metrics for analysis
        history['loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['accuracy'].append(train_acc)
        history['val_accuracy'].append(val_acc)
        
        # Print progress after each epoch
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {train_loss:.4f}, Acc: {train_acc:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
    
    return history  # Return training history

# Train the model and store the training history
history = train(model, train_loader, val_loader, criterion, optimizer, epochs=5)
# Out:
# Epoch [1/5], Loss: 2.3571, Acc: 0.5359, Val Loss: 1.1344, Val Acc: 0.7923
# Epoch [2/5], Loss: 0.9001, Acc: 0.8100, Val Loss: 0.7213, Val Acc: 0.8378
# Epoch [3/5], Loss: 0.6353, Acc: 0.8461, Val Loss: 0.5867, Val Acc: 0.8582
# Epoch [4/5], Loss: 0.5336, Acc: 0.8688, Val Loss: 0.5003, Val Acc: 0.8692
# Epoch [5/5], Loss: 0.4595, Acc: 0.8833, Val Loss: 0.4982, Val Acc: 0.8659

# %% [markdown]
# 6. Save the model to file, so you can later load your trained model without having to go through training again.

# %%
# Save model checkpoint
 # save the loss and metric history along with the model
checkpoint_path = "model_cal_tech_inception_v3.pth"
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'val_loss': history["val_loss"][-1],
    'history': history 
}, checkpoint_path)

# %%
# import requests
# url="" # Get the dictionary containing each metric and the loss for each epoch
# output_path="model_cal_tech_inception_v3.pth"

# # Download the file
# if not os.path.exists(output_path):
#     response = requests.get(url, stream=True)
#     with open(output_path, "wb") as file:
#         for chunk in response.iter_content(chunk_size=1024):
#             if chunk:
#                 file.write(chunk)
#     print("Download complete.")

# %%
# Load a pre-trained model (Inception v3)
# Modify the final classification layer to match the number of classes
# restored_model_pooling = inception_v3()  # Ensure the same architecture
# restored_model_pooling.load_state_dict(torch.load("model_cal_tech_inception_v3.pth", weights_only=True)["model_state_dict"])
# restored_model_pooling.eval()
# history = torch.load("model_cal_tech_inception_v3.pth", weights_only=True)["history"]

# 1. Charger le checkpoint
checkpoint = torch.load("model_cal_tech_inception_v3.pth", weights_only=True)

# 2. Recréer le modèle de base
restored_model_pooling = models.inception_v3(weights=None)  # Pas besoin des poids ImageNet

# 3. Déterminer le nombre de classes depuis le checkpoint
num_classes = checkpoint["model_state_dict"]["fc.0.weight"].shape[0]
print(f"📊 Nombre de classes : {num_classes}")

# 4. Recréer EXACTEMENT la même structure que pendant l'entraînement
restored_model_pooling.fc = nn.Sequential(
    nn.Linear(restored_model_pooling.fc.in_features, num_classes)
    # Pas de Softmax ! CrossEntropyLoss s'en occupe
)

# 5. Charger les poids sauvegardés
restored_model_pooling.load_state_dict(checkpoint["model_state_dict"])

# 6. Mode évaluation
restored_model_pooling.eval()

# 7. Récupérer l'historique
history = checkpoint["history"]

print("✅ Modèle restauré avec succès !")
print(f"📈 Dernière val_loss : {checkpoint['val_loss']:.4f}")
# Out:
# 📊 Nombre de classes : 102
# ✅ Modèle restauré avec succès !
# 📈 Dernière val_loss : 0.4982

# %%
# load the model weights into the model class thanks to the state dict

# %%
# alternatively you may load the whole model with option weights_only=False

# %% [markdown]
# 6. Visualize your `accuracy` on your `train` and on your `test` thanks to the attribute `history` of your model

# %%
from plotly import graph_objects as go
color_chart = ["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]

fig = go.Figure(data=[
                      go.Scatter(
                          y=history["accuracy"],
                          name="Training loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[0]
                          )),
                      go.Scatter(
                          y=history["val_accuracy"],
                          name="Validation loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[1]
                          ))
])
fig.update_layout(
    title='Training and val loss across epochs',
    xaxis_title='epochs',
    yaxis_title='Cross Entropy'    
)
fig.show()

# %% [markdown]
# 7. Do the same for your `loss`

# %%
from plotly import graph_objects as go
color_chart = ["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]

fig = go.Figure(data=[
                      go.Scatter(
                          y=history["loss"],
                          name="Training loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[0]
                          )),
                      go.Scatter(
                          y=history["val_loss"],
                          name="Validation loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[1]
                          ))
])
fig.update_layout(
    title='Training and val loss across epochs',
    xaxis_title='epochs',
    yaxis_title='Cross Entropy'    
)
fig.show()

# %% [markdown]
# # Fine-Tuning
#
# 1. Count the number of layers in your pre-trained model

# %%
# Load the base model
# count the elements thanks to the .modules() method
  # Includes all submodules

modules_list = list(restored_model_pooling.modules())
print(f"📊 Nombre total de modules : {len(modules_list)}")

print("🔍 Types de modules dans le modèle :\n")
for i, module in enumerate(restored_model_pooling.modules()):
    print(f"{i}: {type(module).__name__}")
# Out:
# 📊 Nombre total de modules : 308
# 🔍 Types de modules dans le modèle :
#
# 0: Inception3
# 1: BasicConv2d
# 2: Conv2d
# 3: BatchNorm2d
# 4: BasicConv2d
# 5: Conv2d
# 6: BatchNorm2d
# 7: BasicConv2d
# 8: Conv2d
# 9: BatchNorm2d
# 10: MaxPool2d
# 11: BasicConv2d
# 12: Conv2d
# 13: BatchNorm2d
# 14: BasicConv2d
# 15: Conv2d
# 16: BatchNorm2d
# 17: MaxPool2d
# 18: InceptionA
# 19: BasicConv2d
# 20: Conv2d
# 21: BatchNorm2d
# 22: BasicConv2d
# 23: Conv2d
# 24: BatchNorm2d
# 25: BasicConv2d
# 26: Conv2d
# 27: BatchNorm2d
# 28: BasicConv2d
# 29: Conv2d
# 30: BatchNorm2d
# 31: BasicConv2d
# 32: Conv2d
# 33: BatchNorm2d
# 34: BasicConv2d
# 35: Conv2d
# 36: BatchNorm2d
# 37: BasicConv2d
# 38: Conv2d
# 39: BatchNorm2d
# 40: InceptionA
# 41: BasicConv2d
# 42: Conv2d
# 43: BatchNorm2d
# 44: BasicConv2d
# 45: Conv2d
# 46: BatchNorm2d
# 47: BasicConv2d
# 48: Conv2d
# 49: BatchNorm2d
# 50: BasicConv2d
# 51: Conv2d
# 52: BatchNorm2d
# 53: BasicConv2d
# 54: Conv2d
# 55: BatchNorm2d
# 56: BasicConv2d
# 57: Conv2d
# 58: BatchNorm2d
# 59: BasicConv2d
# 60: Conv2d
# 61: BatchNorm2d
# 62: InceptionA
# 63: BasicConv2d
# 64: Conv2d
# 65: BatchNorm2d
# 66: BasicConv2d
# 67: Conv2d
# 68: BatchNorm2d
# 69: BasicConv2d
# 70: Conv2d
# 71: BatchNorm2d
# 72: BasicConv2d
# 73: Conv2d
# 74: BatchNorm2d
# 75: BasicConv2d
# 76: Conv2d
# 77: BatchNorm2d
# 78: BasicConv2d
# 79: Conv2d
# 80: BatchNorm2d
# 81: BasicConv2d
# 82: Conv2d
# 83: BatchNorm2d
# 84: InceptionB
# 85: BasicConv2d
# 86: Conv2d
# 87: BatchNorm2d
# 88: BasicConv2d
# 89: Conv2d
# 90: BatchNorm2d
# 91: BasicConv2d
# 92: Conv2d
# 93: BatchNorm2d
# 94: BasicConv2d
# 95: Conv2d
# 96: BatchNorm2d
# 97: InceptionC
# 98: BasicConv2d
# 99: Conv2d
# 100: BatchNorm2d
# 101: BasicConv2d
# 102: Conv2d
# 103: BatchNorm2d
# 104: BasicConv2d
# 105: Conv2d
# 106: BatchNorm2d
# 107: BasicConv2d
# 108: Conv2d
# 109: BatchNorm2d
# 110: BasicConv2d
# 111: Conv2d
# 112: BatchNorm2d
# 113: BasicConv2d
# 114: Conv2d
# 115: BatchNorm2d
# 116: BasicConv2d
# 117: Conv2d
# 118: BatchNorm2d
# 119: BasicConv2d
# 120: Conv2d
# 121: BatchNorm2d
# 122: BasicConv2d
# 123: Conv2d
# 124: BatchNorm2d
# 125: BasicConv2d
# 126: Conv2d
# 127: BatchNorm2d
# 128: InceptionC
# 129: BasicConv2d
# 130: Conv2d
# 131: BatchNorm2d
# 132: BasicConv2d
# 133: Conv2d
# 134: BatchNorm2d
# 135: BasicConv2d
# 136: Conv2d
# 137: BatchNorm2d
# 138: BasicConv2d
# 139: Conv2d
# 140: BatchNorm2d
# 141: BasicConv2d
# 142: Conv2d
# 143: BatchNorm2d
# 144: BasicConv2d
# 145: Conv2d
# 146: BatchNorm2d
# 147: BasicConv2d
# 148: Conv2d
# 149: BatchNorm2d
# 150: BasicConv2d
# 151: Conv2d
# 152: BatchNorm2d
# 153: BasicConv2d
# 154: Conv2d
# 155: BatchNorm2d
# 156: BasicConv2d
# 157: Conv2d
# 158: BatchNorm2d
# 159: InceptionC
# 160: BasicConv2d
# 161: Conv2d
# 162: BatchNorm2d
# 163: BasicConv2d
# 164: Conv2d
# 165: BatchNorm2d
# 166: BasicConv2d
# 167: Conv2d
# 168: BatchNorm2d
# 169: BasicConv2d
# 170: Conv2d
# 171: BatchNorm2d
# 172: BasicConv2d
# 173: Conv2d
# 174: BatchNorm2d
# 175: BasicConv2d
# 176: Conv2d
# 177: BatchNorm2d
# 178: BasicConv2d
# 179: Conv2d
# 180: BatchNorm2d
# 181: BasicConv2d
# 182: Conv2d
# 183: BatchNorm2d
# 184: BasicConv2d
# 185: Conv2d
# 186: BatchNorm2d
# 187: BasicConv2d
# 188: Conv2d
# 189: BatchNorm2d
# 190: InceptionC
# 191: BasicConv2d
# 192: Conv2d
# 193: BatchNorm2d
# 194: BasicConv2d
# 195: Conv2d
# 196: BatchNorm2d
# 197: BasicConv2d
# 198: Conv2d
# 199: BatchNorm2d
# 200: BasicConv2d
# 201: Conv2d
# 202: BatchNorm2d
# 203: BasicConv2d
# 204: Conv2d
# 205: BatchNorm2d
# 206: BasicConv2d
# 207: Conv2d
# 208: BatchNorm2d
# 209: BasicConv2d
# 210: Conv2d
# 211: BatchNorm2d
# 212: BasicConv2d
# 213: Conv2d
# 214: BatchNorm2d
# 215: BasicConv2d
# 216: Conv2d
# 217: BatchNorm2d
# 218: BasicConv2d
# 219: Conv2d
# 220: BatchNorm2d
# 221: InceptionAux
# 222: BasicConv2d
# 223: Conv2d
# 224: BatchNorm2d
# 225: BasicConv2d
# 226: Conv2d
# 227: BatchNorm2d
# 228: Linear
# 229: InceptionD
# 230: BasicConv2d
# 231: Conv2d
# 232: BatchNorm2d
# 233: BasicConv2d
# 234: Conv2d
# 235: BatchNorm2d
# 236: BasicConv2d
# 237: Conv2d
# 238: BatchNorm2d
# 239: BasicConv2d
# 240: Conv2d
# 241: BatchNorm2d
# 242: BasicConv2d
# 243: Conv2d
# 244: BatchNorm2d
# 245: BasicConv2d
# 246: Conv2d
# 247: BatchNorm2d
# 248: InceptionE
# 249: BasicConv2d
# 250: Conv2d
# 251: BatchNorm2d
# 252: BasicConv2d
# 253: Conv2d
# 254: BatchNorm2d
# 255: BasicConv2d
# 256: Conv2d
# 257: BatchNorm2d
# 258: BasicConv2d
# 259: Conv2d
# 260: BatchNorm2d
# 261: BasicConv2d
# 262: Conv2d
# 263: BatchNorm2d
# 264: BasicConv2d
# 265: Conv2d
# 266: BatchNorm2d
# 267: BasicConv2d
# 268: Conv2d
# 269: BatchNorm2d
# 270: BasicConv2d
# 271: Conv2d
# 272: BatchNorm2d
# 273: BasicConv2d
# 274: Conv2d
# 275: BatchNorm2d
# 276: InceptionE
# 277: BasicConv2d
# 278: Conv2d
# 279: BatchNorm2d
# 280: BasicConv2d
# 281: Conv2d
# 282: BatchNorm2d
# 283: BasicConv2d
# 284: Conv2d
# 285: BatchNorm2d
# 286: BasicConv2d
# 287: Conv2d
# 288: BatchNorm2d
# 289: BasicConv2d
# 290: Conv2d
# 291: BatchNorm2d
# 292: BasicConv2d
# 293: Conv2d
# 294: BatchNorm2d
# 295: BasicConv2d
# 296: Conv2d
# 297: BatchNorm2d
# 298: BasicConv2d
# 299: Conv2d
# 300: BatchNorm2d
# 301: BasicConv2d
# 302: Conv2d
# 303: BatchNorm2d
# 304: AdaptiveAvgPool2d
# 305: Dropout
# 306: Sequential
# 307: Linear

# %% [markdown]
# 2. Let about 10% of the layers towards the top in trainable status and freeze the rest. You will have to load the pre-trained model again.

# %%
# Unfreeze last 10 layers for fine-tuning
# Si vous voulez vraiment dégeler les 10 derniers MODULES :
children_list = list(restored_model_pooling.children())
fine_tune_at = len(children_list) - 10

# Geler tout d'abord
for param in restored_model_pooling.parameters():
    param.requires_grad = False

# Dégeler seulement les 10 derniers modules
for module in children_list[fine_tune_at:]:
    for param in module.parameters():
        param.requires_grad = True

print(f"🔓 {len(children_list[fine_tune_at:])} modules dégelés")
# Out:
# 🔓 10 modules dégelés

# %%
# Move model to device
# 1. Détecter automatiquement si un GPU est disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🖥️  Device utilisé : {device}")

# 2. Déplacer le modèle vers ce device
restored_model_pooling = restored_model_pooling.to(device)

print("✅ Modèle déplacé vers le device !")
# Out:
# 🖥️  Device utilisé : cpu
# ✅ Modèle déplacé vers le device !

# %%
from torchinfo import summary

# Print model summary
# Print model summary
summary(restored_model_pooling, input_size=(1, 3, 299, 299))  # (batch_size, input_features)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Inception3                               [1, 102]                  3,326,696
# ├─BasicConv2d: 1-1                       [1, 32, 149, 149]         --
# │    └─Conv2d: 2-1                       [1, 32, 149, 149]         (864)
# │    └─BatchNorm2d: 2-2                  [1, 32, 149, 149]         (64)
# ├─BasicConv2d: 1-2                       [1, 32, 147, 147]         --
# │    └─Conv2d: 2-3                       [1, 32, 147, 147]         (9,216)
# │    └─BatchNorm2d: 2-4                  [1, 32, 147, 147]         (64)
# ├─BasicConv2d: 1-3                       [1, 64, 147, 147]         --
# │    └─Conv2d: 2-5                       [1, 64, 147, 147]         (18,432)
# │    └─BatchNorm2d: 2-6                  [1, 64, 147, 147]         (128)
# ├─MaxPool2d: 1-4                         [1, 64, 73, 73]           --
# ├─BasicConv2d: 1-5                       [1, 80, 73, 73]           --
# │    └─Conv2d: 2-7                       [1, 80, 73, 73]           (5,120)
# │    └─BatchNorm2d: 2-8                  [1, 80, 73, 73]           (160)
# ├─BasicConv2d: 1-6                       [1, 192, 71, 71]          --
# │    └─Conv2d: 2-9                       [1, 192, 71, 71]          (138,240)
# │    └─BatchNorm2d: 2-10                 [1, 192, 71, 71]          (384)
# ├─MaxPool2d: 1-7                         [1, 192, 35, 35]          --
# ├─InceptionA: 1-8                        [1, 256, 35, 35]          --
# │    └─BasicConv2d: 2-11                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-1                  [1, 64, 35, 35]           (12,288)
# │    │    └─BatchNorm2d: 3-2             [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-12                 [1, 48, 35, 35]           --
# │    │    └─Conv2d: 3-3                  [1, 48, 35, 35]           (9,216)
# │    │    └─BatchNorm2d: 3-4             [1, 48, 35, 35]           (96)
# │    └─BasicConv2d: 2-13                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-5                  [1, 64, 35, 35]           (76,800)
# │    │    └─BatchNorm2d: 3-6             [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-14                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-7                  [1, 64, 35, 35]           (12,288)
# │    │    └─BatchNorm2d: 3-8             [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-15                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-9                  [1, 96, 35, 35]           (55,296)
# │    │    └─BatchNorm2d: 3-10            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-16                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-11                 [1, 96, 35, 35]           (82,944)
# │    │    └─BatchNorm2d: 3-12            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-17                 [1, 32, 35, 35]           --
# │    │    └─Conv2d: 3-13                 [1, 32, 35, 35]           (6,144)
# │    │    └─BatchNorm2d: 3-14            [1, 32, 35, 35]           (64)
# ├─InceptionA: 1-9                        [1, 288, 35, 35]          --
# │    └─BasicConv2d: 2-18                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-15                 [1, 64, 35, 35]           (16,384)
# │    │    └─BatchNorm2d: 3-16            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-19                 [1, 48, 35, 35]           --
# │    │    └─Conv2d: 3-17                 [1, 48, 35, 35]           (12,288)
# │    │    └─BatchNorm2d: 3-18            [1, 48, 35, 35]           (96)
# │    └─BasicConv2d: 2-20                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-19                 [1, 64, 35, 35]           (76,800)
# │    │    └─BatchNorm2d: 3-20            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-21                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-21                 [1, 64, 35, 35]           (16,384)
# │    │    └─BatchNorm2d: 3-22            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-22                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-23                 [1, 96, 35, 35]           (55,296)
# │    │    └─BatchNorm2d: 3-24            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-23                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-25                 [1, 96, 35, 35]           (82,944)
# │    │    └─BatchNorm2d: 3-26            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-24                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-27                 [1, 64, 35, 35]           (16,384)
# │    │    └─BatchNorm2d: 3-28            [1, 64, 35, 35]           (128)
# ├─InceptionA: 1-10                       [1, 288, 35, 35]          --
# │    └─BasicConv2d: 2-25                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-29                 [1, 64, 35, 35]           (18,432)
# │    │    └─BatchNorm2d: 3-30            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-26                 [1, 48, 35, 35]           --
# │    │    └─Conv2d: 3-31                 [1, 48, 35, 35]           (13,824)
# │    │    └─BatchNorm2d: 3-32            [1, 48, 35, 35]           (96)
# │    └─BasicConv2d: 2-27                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-33                 [1, 64, 35, 35]           (76,800)
# │    │    └─BatchNorm2d: 3-34            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-28                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-35                 [1, 64, 35, 35]           (18,432)
# │    │    └─BatchNorm2d: 3-36            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-29                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-37                 [1, 96, 35, 35]           (55,296)
# │    │    └─BatchNorm2d: 3-38            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-30                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-39                 [1, 96, 35, 35]           (82,944)
# │    │    └─BatchNorm2d: 3-40            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-31                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-41                 [1, 64, 35, 35]           (18,432)
# │    │    └─BatchNorm2d: 3-42            [1, 64, 35, 35]           (128)
# ├─InceptionB: 1-11                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-32                 [1, 384, 17, 17]          --
# │    │    └─Conv2d: 3-43                 [1, 384, 17, 17]          (995,328)
# │    │    └─BatchNorm2d: 3-44            [1, 384, 17, 17]          (768)
# │    └─BasicConv2d: 2-33                 [1, 64, 35, 35]           --
# │    │    └─Conv2d: 3-45                 [1, 64, 35, 35]           (18,432)
# │    │    └─BatchNorm2d: 3-46            [1, 64, 35, 35]           (128)
# │    └─BasicConv2d: 2-34                 [1, 96, 35, 35]           --
# │    │    └─Conv2d: 3-47                 [1, 96, 35, 35]           (55,296)
# │    │    └─BatchNorm2d: 3-48            [1, 96, 35, 35]           (192)
# │    └─BasicConv2d: 2-35                 [1, 96, 17, 17]           --
# │    │    └─Conv2d: 3-49                 [1, 96, 17, 17]           (82,944)
# │    │    └─BatchNorm2d: 3-50            [1, 96, 17, 17]           (192)
# ├─InceptionC: 1-12                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-36                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-51                 [1, 192, 17, 17]          (147,456)
# │    │    └─BatchNorm2d: 3-52            [1, 192, 17, 17]          (384)
# │    └─BasicConv2d: 2-37                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-53                 [1, 128, 17, 17]          (98,304)
# │    │    └─BatchNorm2d: 3-54            [1, 128, 17, 17]          (256)
# │    └─BasicConv2d: 2-38                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-55                 [1, 128, 17, 17]          (114,688)
# │    │    └─BatchNorm2d: 3-56            [1, 128, 17, 17]          (256)
# │    └─BasicConv2d: 2-39                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-57                 [1, 192, 17, 17]          (172,032)
# │    │    └─BatchNorm2d: 3-58            [1, 192, 17, 17]          (384)
# │    └─BasicConv2d: 2-40                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-59                 [1, 128, 17, 17]          (98,304)
# │    │    └─BatchNorm2d: 3-60            [1, 128, 17, 17]          (256)
# │    └─BasicConv2d: 2-41                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-61                 [1, 128, 17, 17]          (114,688)
# │    │    └─BatchNorm2d: 3-62            [1, 128, 17, 17]          (256)
# │    └─BasicConv2d: 2-42                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-63                 [1, 128, 17, 17]          (114,688)
# │    │    └─BatchNorm2d: 3-64            [1, 128, 17, 17]          (256)
# │    └─BasicConv2d: 2-43                 [1, 128, 17, 17]          --
# │    │    └─Conv2d: 3-65                 [1, 128, 17, 17]          (114,688)
# │    │    └─BatchNorm2d: 3-66            [1, 128, 17, 17]          (256)
# │    └─BasicConv2d: 2-44                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-67                 [1, 192, 17, 17]          (172,032)
# │    │    └─BatchNorm2d: 3-68            [1, 192, 17, 17]          (384)
# │    └─BasicConv2d: 2-45                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-69                 [1, 192, 17, 17]          (147,456)
# │    │    └─BatchNorm2d: 3-70            [1, 192, 17, 17]          (384)
# ├─InceptionC: 1-13                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-46                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-71                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-72            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-47                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-73                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-74            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-48                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-75                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-76            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-49                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-77                 [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-78            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-50                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-79                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-80            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-51                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-81                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-82            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-52                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-83                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-84            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-53                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-85                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-86            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-54                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-87                 [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-88            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-55                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-89                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-90            [1, 192, 17, 17]          384
# ├─InceptionC: 1-14                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-56                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-91                 [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-92            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-57                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-93                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-94            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-58                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-95                 [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-96            [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-59                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-97                 [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-98            [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-60                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-99                 [1, 160, 17, 17]          122,880
# │    │    └─BatchNorm2d: 3-100           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-61                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-101                [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-102           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-62                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-103                [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-104           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-63                 [1, 160, 17, 17]          --
# │    │    └─Conv2d: 3-105                [1, 160, 17, 17]          179,200
# │    │    └─BatchNorm2d: 3-106           [1, 160, 17, 17]          320
# │    └─BasicConv2d: 2-64                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-107                [1, 192, 17, 17]          215,040
# │    │    └─BatchNorm2d: 3-108           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-65                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-109                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-110           [1, 192, 17, 17]          384
# ├─InceptionC: 1-15                       [1, 768, 17, 17]          --
# │    └─BasicConv2d: 2-66                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-111                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-112           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-67                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-113                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-114           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-68                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-115                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-116           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-69                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-117                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-118           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-70                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-119                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-120           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-71                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-121                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-122           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-72                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-123                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-124           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-73                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-125                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-126           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-74                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-127                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-128           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-75                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-129                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-130           [1, 192, 17, 17]          384
# ├─InceptionD: 1-16                       [1, 1280, 8, 8]           --
# │    └─BasicConv2d: 2-76                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-131                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-132           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-77                 [1, 320, 8, 8]            --
# │    │    └─Conv2d: 3-133                [1, 320, 8, 8]            552,960
# │    │    └─BatchNorm2d: 3-134           [1, 320, 8, 8]            640
# │    └─BasicConv2d: 2-78                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-135                [1, 192, 17, 17]          147,456
# │    │    └─BatchNorm2d: 3-136           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-79                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-137                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-138           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-80                 [1, 192, 17, 17]          --
# │    │    └─Conv2d: 3-139                [1, 192, 17, 17]          258,048
# │    │    └─BatchNorm2d: 3-140           [1, 192, 17, 17]          384
# │    └─BasicConv2d: 2-81                 [1, 192, 8, 8]            --
# │    │    └─Conv2d: 3-141                [1, 192, 8, 8]            331,776
# │    │    └─BatchNorm2d: 3-142           [1, 192, 8, 8]            384
# ├─InceptionE: 1-17                       [1, 2048, 8, 8]           --
# │    └─BasicConv2d: 2-82                 [1, 320, 8, 8]            --
# │    │    └─Conv2d: 3-143                [1, 320, 8, 8]            409,600
# │    │    └─BatchNorm2d: 3-144           [1, 320, 8, 8]            640
# │    └─BasicConv2d: 2-83                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-145                [1, 384, 8, 8]            491,520
# │    │    └─BatchNorm2d: 3-146           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-84                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-147                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-148           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-85                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-149                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-150           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-86                 [1, 448, 8, 8]            --
# │    │    └─Conv2d: 3-151                [1, 448, 8, 8]            573,440
# │    │    └─BatchNorm2d: 3-152           [1, 448, 8, 8]            896
# │    └─BasicConv2d: 2-87                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-153                [1, 384, 8, 8]            1,548,288
# │    │    └─BatchNorm2d: 3-154           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-88                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-155                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-156           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-89                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-157                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-158           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-90                 [1, 192, 8, 8]            --
# │    │    └─Conv2d: 3-159                [1, 192, 8, 8]            245,760
# │    │    └─BatchNorm2d: 3-160           [1, 192, 8, 8]            384
# ├─InceptionE: 1-18                       [1, 2048, 8, 8]           --
# │    └─BasicConv2d: 2-91                 [1, 320, 8, 8]            --
# │    │    └─Conv2d: 3-161                [1, 320, 8, 8]            655,360
# │    │    └─BatchNorm2d: 3-162           [1, 320, 8, 8]            640
# │    └─BasicConv2d: 2-92                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-163                [1, 384, 8, 8]            786,432
# │    │    └─BatchNorm2d: 3-164           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-93                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-165                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-166           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-94                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-167                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-168           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-95                 [1, 448, 8, 8]            --
# │    │    └─Conv2d: 3-169                [1, 448, 8, 8]            917,504
# │    │    └─BatchNorm2d: 3-170           [1, 448, 8, 8]            896
# │    └─BasicConv2d: 2-96                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-171                [1, 384, 8, 8]            1,548,288
# │    │    └─BatchNorm2d: 3-172           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-97                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-173                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-174           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-98                 [1, 384, 8, 8]            --
# │    │    └─Conv2d: 3-175                [1, 384, 8, 8]            442,368
# │    │    └─BatchNorm2d: 3-176           [1, 384, 8, 8]            768
# │    └─BasicConv2d: 2-99                 [1, 192, 8, 8]            --
# │    │    └─Conv2d: 3-177                [1, 192, 8, 8]            393,216
# │    │    └─BatchNorm2d: 3-178           [1, 192, 8, 8]            384
# ├─AdaptiveAvgPool2d: 1-19                [1, 2048, 1, 1]           --
# ├─Dropout: 1-20                          [1, 2048, 1, 1]           --
# ├─Sequential: 1-21                       [1, 102]                  --
# │    └─Linear: 2-100                     [1, 102]                  208,998
# ==========================================================================================
# Total params: 25,321,262
# Trainable params: 21,879,374
# Non-trainable params: 3,441,888
# Total mult-adds (G): 5.71
# ==========================================================================================
# Input size (MB): 1.07
# Forward/backward pass size (MB): 143.48
# Params size (MB): 87.98
# Estimated Total Size (MB): 232.53
# ==========================================================================================

# %% [markdown]
# 5. Train the model for 5 epochs.

# %%
# define the Adam optimizer
 # send model to device
# start training

# %%
# Save model checkpoint
 # save the loss and metric history along with the model

# %%
import requests
url="" # Get the dictionary containing each metric and the loss for each epoch
output_path="cal_tech_inception_v3_finetuned.pth"

# Download the file
if not os.path.exists(output_path):
    response = requests.get(url, stream=True)
    with open(output_path, "wb") as file:
        for chunk in response.iter_content(chunk_size=1024):
            if chunk:
                file.write(chunk)
    print("Download complete.")

# %%
# Define the model class

# Load the model weights into the model class

# %%
# Alternatively you may load the model with weights_only = False

# %% [markdown]
# 6. Visualize your `accuracy` on your `train` and on your `test`

# %%
from plotly import graph_objects as go
color_chart = ["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]

fig = go.Figure(data=[
                      go.Scatter(
                          y=history_finetune["accuracy"],
                          name="Training loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[0]
                          )),
                      go.Scatter(
                          y=history_finetune["val_accuracy"],
                          name="Validation loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[1]
                          ))
])
fig.update_layout(
    title='Training and val loss across epochs',
    xaxis_title='epochs',
    yaxis_title='Cross Entropy'    
)
fig.show()

# %% [markdown]
# 7. Do the same for your `loss`

# %%
from plotly import graph_objects as go
color_chart = ["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]

fig = go.Figure(data=[
                      go.Scatter(
                          y=history_finetune["loss"],
                          name="Training loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[0]
                          )),
                      go.Scatter(
                          y=history_finetune["val_loss"],
                          name="Validation loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[1]
                          ))
])
fig.update_layout(
    title='Training and val loss across epochs',
    xaxis_title='epochs',
    yaxis_title='Cross Entropy'    
)
fig.show()

# %% [markdown]
# # Interpretation with Grad Cam
#
# 1. Create an object `imgs` and an object `labels` containing a batch of validation images and validation labels.

# %% [markdown]
# 2. Get the name of the last convolution layer of the pretrained model.

# %% [markdown]
# The last convolutional layer is called `Mixes_7c`.

# %% [markdown]
# 3. Produce the grad cam for all images in the batch

# %%
import requests
import json

# Convert into a dictionary of {class_idx: class_name}

# Example: Get class name for index 4
  # Output: 'Motorbikes'

# %%
import torch
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# 1️⃣ Load the Pretrained InceptionV3 model
# Set to evaluation mode

# 2️⃣ Choose the target layer (the last convolutional layer)

# 3️⃣ Preprocessing Function for Files
# Define a function to preprocess images by resizing, normalizing, and converting them to tensors.

    # Resize the image to the required input size for InceptionV3 (299x299 pixels)
    
    # Convert the image to a PyTorch tensor
    
    # Normalize pixel values to match the expected input distribution

    # Open the image, convert to RGB, apply transformations, and add a batch dimension

# 4️⃣ Hook to Extract Gradients & Features
# Define the GradCAM class to extract feature maps and gradients from a target layer.

    # Initialize the model, target layer, and storage for gradients & features
    
    # Register hooks for capturing the intermediate layer's forward and backward passes

    # Hook function to store feature maps during the forward pass

    # Hook function to store gradients during the backward pass

    # Generate Grad-CAM heatmap from an input tensor
    
        # Perform a forward pass through

# %%
# 🔥 **Test with an Image**
  # Replace with your image path
    # 🔥 **Test with a Tensor**
     # Remove batch dimension

# %% [markdown]
# This grad cam logic helps us dive deeper into the model's stength, and weakness, as well as identify biases in out dataset.
#
# 4. What bias can you identify in our dataset that the grad cam enables us to pickup, and how could we solve this problem ?
